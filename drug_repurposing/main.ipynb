# %%
import numpy as np
import pandas as pd
import torch
from load_msi import create_msi
from visualization import (
        generate_nx_graph, generate_khop_subgraph, generate_pyvis_graph, 
        visualize_tsne_embeddings, visualize_pca_embeddings)
from training import split_data, create_minibatches, train_link_predictor
from torch_geometric.utils import to_networkx, degree
from torch_geometric.nn import to_hetero

from gnn import GAT, GIN, DotProductLinkPredictor
import torch_geometric.transforms as T
print(torch.__version__)
# Out:
# 1.13.1+cu117

# %%
msi = create_msi("msi", 
                 num_features = 1,
                 data_dir="../multiscale_interactome/data")

data = msi.hetero_data
#data = T.ToUndirected()(data)

# %%
# Generate and visualize graphs (HIV: id = C0019693, gid = 840)
##G, G_undirected = generate_nx_graph(msi.data)
##subG = generate_khop_subgraph(msi, G, 840, 1)
##py_graph = generate_pyvis_graph(subG)
##py_graph.show("test.html")

# %%
# Set the device.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
print("Average number of 1-hop neighbors per node of edge type\n")
for edge_type in data.edge_types:
    degrees = degree(data[edge_type].edge_index[0]).numpy()
    print(f"{edge_type} : {np.mean(degrees):.1f}")
# Out:
# Average number of 1-hop neighbors per node of edge type
#
# ('drug', 'binds', 'prot') : 5.2
# ('dz', 'implicates', 'prot') : 30.0
# ('prot', 'associates', 'prot') : 64.0
# ('prot', 'partOf', 'func') : 2.9
# ('func', 'partOf', 'func') : 4.6
# ('drug', 'treats', 'dz') : 3.6
# ('prot', 'rev_binds', 'drug') : 0.7
# ('prot', 'rev_implicates', 'dz') : 2.1
# ('func', 'rev_partOf', 'prot') : 5.4
# ('dz', 'rev_treats', 'drug') : 7.1

# %%
# Prepare data for GNN.
edge_types = ("drug", "treats", "dz")
rev_edge_types = ("dz", "rev_treats", "drug")

# Split the data into train, validation, and test sets.
train_data, val_data, test_data = split_data(
        data, val_size=0.1, test_size=0.1, supervision_ratio=0.3,
        edge_types=edge_types, neg_sampling_ratio=1.0,
        rev_edge_types=rev_edge_types)




# Create minibatches.
train_loader = create_minibatches(
        train_data, edge_types=edge_types, #num_khop_neighbors=[50,25,10], 
        neg_sampling_ratio=1.0, batch_size=16)
val_loader = create_minibatches(
        val_data, edge_types=edge_types, #num_khop_neighbors = [50,25,10],
        batch_size=16)
test_loader = create_minibatches(
        test_data, edge_types=edge_types, #num_khop_neighbors = [50,25,10],
        batch_size=16)

# %%
# Instantiate the model and generate some initial node embeddings prior to training.
model = GAT(4, 64, 16)
model = to_hetero(model, data.metadata(), aggr='sum').to(device)
predictor = DotProductLinkPredictor(32, 32, 1).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
#model.reset_parameters()
#predictor.reset_parameters()

# Train and validate the model for a given number of epochs.
for epoch in range(1, 50+1):
    
    # Training..
    loss, auc = train_link_predictor(
            model, predictor, "drug", "dz", edge_types=edge_types, 
            loader=train_loader, optimizer=optimizer, device=device, train=True)
    
    # Validation.
    val_loss, val_auc = train_link_predictor(
            model, predictor, "drug", "dz", edge_types=edge_types, 
            loader=val_loader,  optimizer=optimizer, device=device, train=False)
    
    print(f"Epoch     : {epoch}")
    print(f" Loss     : {loss:<10.4f} |     AUC:     {auc:>10.4f}")
    print(f" Val_Loss : {val_loss:<10.4f} |     Val_AUC: {val_auc:>10.4f}")
# Out:
# 100%|██████████| 89/89 [00:09<00:00,  9.48it/s]
# 100%|██████████| 74/74 [00:02<00:00, 25.75it/s]
# Epoch     : 1
#  Loss     : 1.1122     |     AUC:         0.7034
#  Val_Loss : 0.6810     |     Val_AUC:     0.7468
# 100%|██████████| 89/89 [00:08<00:00, 10.27it/s]
# 100%|██████████| 74/74 [00:02<00:00, 25.58it/s]
# Epoch     : 2
#  Loss     : 0.6159     |     AUC:         0.7678
#  Val_Loss : 0.6110     |     Val_AUC:     0.7652
# 100%|██████████| 89/89 [00:08<00:00, 10.22it/s]
# 100%|██████████| 74/74 [00:02<00:00, 25.90it/s]
# Epoch     : 3
#  Loss     : 0.5707     |     AUC:         0.8020
#  Val_Loss : 0.5942     |     Val_AUC:     0.7908
# 100%|██████████| 89/89 [00:08<00:00, 10.33it/s]
# 100%|██████████| 74/74 [00:02<00:00, 25.67it/s]
# Epoch     : 4
#  Loss     : 0.5576     |     AUC:         0.8159
#  Val_Loss : 0.5143     |     Val_AUC:     0.8263
# 100%|██████████| 89/89 [00:08<00:00, 10.47it/s]
# 100%|██████████| 74/74 [00:02<00:00, 26.45it/s]
# Epoch     : 5
#  Loss     : 0.5664     |     AUC:         0.8110
#  Val_Loss : 0.5296     |     Val_AUC:     0.8217
# 100%|██████████| 89/89 [00:08<00:00, 10.43it/s]
# 100%|██████████| 74/74 [00:02<00:00, 26.05it/s]
# Epoch     : 6
#  Loss     : 0.5566     |     AUC:         0.8018
#  Val_Loss : 0.5057     |     Val_AUC:     0.8461
# 100%|██████████| 89/89 [00:08<00:00, 10.48it/s]
# 100%|██████████| 74/74 [00:02<00:00, 26.59it/s]
# Epoch     : 7
#  Loss     : 0.5216     |     AUC:         0.8303
#  Val_Loss : 0.4979     |     Val_AUC:     0.8457
# 100%|██████████| 89/89 [00:08<00:00, 10.52it/s]
# 100%|██████████| 74/74 [00:02<00:00, 26.23it/s]
# Epoch     : 8
#  Loss     : 0.5347     |     AUC:         0.8229
#  Val_Loss : 0.5132     |     Val_AUC:     0.8526
# 100%|██████████| 89/89 [00:08<00:00, 10.45it/s]
# 100%|██████████| 74/74 [00:02<00:00, 26.47it/s]
# Epoch     : 9
#  Loss     : 0.5421     |     AUC:         0.8175
#  Val_Loss : 0.5111     |     Val_AUC:     0.8345
# 100%|██████████| 89/89 [00:08<00:00, 10.40it/s]
# 100%|██████████| 74/74 [00:02<00:00, 26.02it/s]
# Epoch     : 10
#  Loss     : 0.5198     |     AUC:         0.8326
#  Val_Loss : 0.5015     |     Val_AUC:     0.8316
#  55%|█████▌    | 49/89 [00:04<00:03, 10.43it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/tmp/ipykernel_1205/4196550958.py in <module>
#       9     loss, auc = train_link_predictor(
#      10             model, predictor, "drug", "dz", edge_types=edge_types,
# ---> 11             loader=train_loader, optimizer=optimizer, device=device, train=True)
#      12
#      13     # Validation.
#
# ~/biographs/drug_repurposing/training.py in train_link_predictor(model, predictor, src_node_type, dest_node_type, edge_types, loader, optimizer, device, train, neg_sampling)
#     159
#     160         # Obtain node embeddings.
# --> 161         z = model(batch.x_dict, batch.edge_index_dict)
#     162
#     163         # Retrieve embeddings for the nodes in the specific edge type.
#
# /opt/conda/lib/python3.7/site-packages/torch/fx/graph_module.py in call_wrapped(self, *args, **kwargs)
#     656
#     657         def call_wrapped(self, *args, **kwargs):
# --> 658             return self._wrapped_call(self, *args, **kwargs)
#     659
#     660         cls.__call__ = call_wrapped
#
# /opt/conda/lib/python3.7/site-packages/torch/fx/graph_module.py in __call__(self, obj, *args, **kwargs)
#     265                 return self.cls_call(obj, *args, **kwargs)
#     266             else:
# --> 267                 return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     268         except Exception as e:
#     269             assert e.__traceback__
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# <eval_with_key>.1 in forward(self, x, edge_index)
#      81     conv3__func2 = self.conv3.func__partOf__func(elu_1__func, edge_index__func__partOf__func)
#      82     conv3__dz1 = self.conv3.drug__treats__dz((elu_1__drug, elu_1__dz), edge_index__drug__treats__dz)
# ---> 83     conv3__drug1 = self.conv3.prot__rev_binds__drug((elu_1__prot, elu_1__drug), edge_index__prot__rev_binds__drug)
#      84     conv3__dz2 = self.conv3.prot__rev_implicates__dz((elu_1__prot, elu_1__dz), edge_index__prot__rev_implicates__dz)
#      85     conv3__prot4 = self.conv3.func__rev_partOf__prot((elu_1__func, elu_1__prot), edge_index__func__rev_partOf__prot)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.7/site-packages/torch_geometric/nn/conv/gatv2_conv.py in forward(self, x, edge_index, edge_attr, return_attention_weights)
#     249         # propagate_type: (x: PairTensor, edge_attr: OptTensor)
#     250         out = self.propagate(edge_index, x=(x_l, x_r), edge_attr=edge_attr,
# --> 251                              size=None)
#     252
#     253         alpha = self._alpha
#
# /opt/conda/lib/python3.7/site-packages/torch_geometric/nn/conv/message_passing.py in propagate(self, edge_index, size, **kwargs)
#     460                                           kwargs)
#     461
# --> 462                 msg_kwargs = self.inspector.distribute('message', coll_dict)
#     463                 for hook in self._message_forward_pre_hooks.values():
#     464                     res = hook(self, (msg_kwargs, ))
#
# /opt/conda/lib/python3.7/site-packages/torch_geometric/nn/conv/utils/inspector.py in distribute(self, func_name, kwargs)
#      52     def distribute(self, func_name, kwargs: Dict[str, Any]):
#      53         out = {}
# ---> 54         for key, param in self.params[func_name].items():
#      55             data = kwargs.get(key, inspect.Parameter.empty)
#      56             if data is inspect.Parameter.empty:
#
# KeyboardInterrupt:

# %%
# Test set.
test_loss, test_auc = train_link_predictor(
        model, predictor, "drug", "dz", edge_types=edge_types, 
        loader=test_loader,  optimizer=optimizer, device=device, train=False)
    
print(f" Test Loss     : {test_loss:<10.4f} |     Test AUC:     {test_auc:>10.4f}")
# Out:
# 100%|██████████| 74/74 [00:02<00:00, 25.27it/s]
#  Test Loss     : 0.4489     |     Test AUC:         0.8682

# %%
data = T.ToUndirected()(data)

# Split the data into train, validation, and test sets.
total_data, _, _ = split_data(
        data, val_size=0.0, test_size=0.0, supervision_ratio=0.3,
        edge_types=edge_types, neg_sampling_ratio=1.0,
        rev_edge_types=rev_edge_types)

total_data_loader = create_minibatches(
        total_data, edge_types=edge_types, #num_khop_neighbors=[50,25,10], 
        neg_sampling_ratio=1.0, batch_size=16)

# Retrain with the entire dataset
for epoch in range(1, 10+1):
    
    # Training with entire dataset...
    loss, auc = train_link_predictor(
            model, predictor, "drug", "dz", edge_types=edge_types, 
            loader=total_data_loader, optimizer=optimizer, device=device, train=True)
    
    print(f"Epoch     : {epoch}")
    print(f" Loss     : {loss:<10.4f} |     AUC:     {auc:>10.4f}")
# Out:
# 100%|██████████| 112/112 [00:11<00:00,  9.35it/s]
# Epoch     : 1
#  Loss     : 0.4988     |     AUC:         0.8433
# 100%|██████████| 112/112 [00:11<00:00,  9.48it/s]
# Epoch     : 2
#  Loss     : 0.5002     |     AUC:         0.8414
# 100%|██████████| 112/112 [00:11<00:00,  9.45it/s]
# Epoch     : 3
#  Loss     : 0.5081     |     AUC:         0.8398
# 100%|██████████| 112/112 [00:11<00:00,  9.37it/s]
# Epoch     : 4
#  Loss     : 0.4955     |     AUC:         0.8482
# 100%|██████████| 112/112 [00:11<00:00,  9.49it/s]
# Epoch     : 5
#  Loss     : 0.4960     |     AUC:         0.8464
# 100%|██████████| 112/112 [00:11<00:00,  9.48it/s]
# Epoch     : 6
#  Loss     : 0.4970     |     AUC:         0.8456
# 100%|██████████| 112/112 [00:11<00:00,  9.46it/s]
# Epoch     : 7
#  Loss     : 0.5068     |     AUC:         0.8390
# 100%|██████████| 112/112 [00:11<00:00,  9.46it/s]
# Epoch     : 8
#  Loss     : 0.4846     |     AUC:         0.8525
# 100%|██████████| 112/112 [00:12<00:00,  9.32it/s]
# Epoch     : 9
#  Loss     : 0.4981     |     AUC:         0.8479
# 100%|██████████| 112/112 [00:11<00:00,  9.42it/s]
# Epoch     : 10
#  Loss     : 0.4900     |     AUC:         0.8468

# %%
# Add hiv information to the msi (HIV: id = C0019693, gid = 840).
msi = create_msi("msi-hiv", 
                 num_features = 1,
                 data_dir="../multiscale_interactome/data", 
                 extra_prot_data="../data/hiv/3_hivProt_humanProt_map.tsv",
                 extra_drug_data="../data/hiv/1b_drugs_prot_map_total.tsv", 
                 extra_dz_data="../data/hiv/2b_hiv_prot_map_total.tsv",
                 extra_drug_dz_links="../data/hiv/4b_drug_hiv_map_total.tsv")

hiv_data = msi.hetero_data
#hiv_data = T.ToUndirected()(hiv_data)

hiv_id = "C0019693"
hiv_gid = 840

# %%
# Send models and data back to cpu.
hiv_data.to("cpu")
model.to("cpu")
predictor.to("cpu")
# Out:
# DotProductLinkPredictor(
#   (lin1): Linear(32, 32, bias=True)
#   (lin2): Linear(32, 1, bias=True)
# )

# %%
#torch.cuda.empty_cache()
#print("torch.cuda.memory_allocated: %fGB"%(torch.cuda.memory_allocated(0)/1024/1024/1024))
#print("torch.cuda.memory_reserved: %fGB"%(torch.cuda.memory_reserved(0)/1024/1024/1024))
#print("torch.cuda.max_memory_reserved: %fGB"%(torch.cuda.max_memory_reserved(0)/1024/1024/1024))
#print(torch.cuda.memory_summary(device=None, abbreviated=False))

# %%
#z = get_node_embeddings(model, hiv_data)
model.eval()
predictor.eval()
z = model(hiv_data.x_dict, hiv_data.edge_index_dict)
z_drugs = z["drug"]
z_dz = z["dz"]
hiv_emb = z_dz[hiv_gid]

# %%
# Predict the drug links to HIV.
drug_edge_preds = []
dz_edge_preds = []
for drug_emb in z_drugs:
    drug_edge_pred = predictor(drug_emb, hiv_emb)
    drug_edge_pred = drug_edge_pred.detach().numpy()
    drug_edge_preds.append(drug_edge_pred)
drug_sorted_edges = np.sort(drug_edge_preds)[::-1]
drug_sorted_ind = np.argsort(drug_edge_preds)[::-1]

# Find dz links to HIV (note: the model was not trained to do this.)
for dz_emb in z_dz:
    dz_edge_pred = predictor(dz_emb, hiv_emb)
    dz_edge_pred = dz_edge_pred.detach().numpy()
    dz_edge_preds.append(dz_edge_pred)
dz_sorted_edges = np.sort(dz_edge_preds)[::-1]
dz_sorted_ind = np.argsort(dz_edge_preds)[::-1]

# %%
import pandas as pd
id_list = []
drug_list = []
sim_list = []
for ind, edge in zip(drug_sorted_ind, drug_sorted_edges):
    id = [i for i in msi.mappings["drug_id_gid_map"] if msi.mappings["drug_id_gid_map"][i] == ind][0]
    drug = msi.mappings["drug_id_name_map"][id]
    id_list.append(id)
    drug_list.append(drug)
    sim_list.append(edge)
    print(f"Drug: {drug:<30}    |    HIV edge pred: {edge:>10.4}")

res_dict = {"id":id_list, "name" : drug_list, "similarity" : sim_list}
res_df = pd.DataFrame(res_dict)

print("\n\n\n")

for ind, edge in zip(dz_sorted_ind, dz_sorted_edges):
    id = [i for i in msi.mappings["dz_id_gid_map"] if msi.mappings["dz_id_gid_map"][i] == ind][0]
    dz = msi.mappings["dz_id_name_map"][id]
    print(f"DZ: {dz:<30}    |    HIV edge pred: {edge:>10.4}")

res_dict = {"id":id_list, "name" : drug_list, "similarity" : sim_list}
res_df = pd.DataFrame(res_dict)
# Out:
# Drug: nan                               |    HIV edge pred:     0.1607
# Drug: cholic-acid                       |    HIV edge pred:     0.1285
# Drug: dapiprazole                       |    HIV edge pred:     0.1263
# Drug: eflornithine                      |    HIV edge pred:      0.104
# Drug: bunazosin                         |    HIV edge pred:    0.09928
# Drug: nan                               |    HIV edge pred:    0.09429
# Drug: acetazolamide                     |    HIV edge pred:    0.08902
# Drug: doluregravir                      |    HIV edge pred:    0.07937
# Drug: nan                               |    HIV edge pred:    0.07474
# Drug: trientine                         |    HIV edge pred:    0.07449
# Drug: Vitamin E                         |    HIV edge pred:    0.06447
# Drug: thiamine                          |    HIV edge pred:    0.06295
# Drug: penicillin-v-potassium            |    HIV edge pred:    0.06143
# Drug: acyclovir                         |    HIV edge pred:    0.05874
# Drug: nan                               |    HIV edge pred:     0.0571
# Drug: nan                               |    HIV edge pred:    0.05628
# Drug: PARATHYROID HORMONE               |    HIV edge pred:    0.05602
# Drug: alprostadil                       |    HIV edge pred:    0.05458
# Drug: nan                               |    HIV edge pred:    0.05345
# Drug: midodrine                         |    HIV edge pred:    0.04685
# Drug: rebamipide                        |    HIV edge pred:    0.04473
# Drug: rilpivirine                       |    HIV edge pred:    0.04435
# Drug: baclofen                          |    HIV edge pred:    0.04414
# Drug: propentofylline                   |    HIV edge pred:    0.04162
# Drug: urea                              |    HIV edge pred:    0.03942
# Drug: nan                               |    HIV edge pred:    0.03834
# Drug: vardenafil                        |    HIV edge pred:    0.03356
# Drug: voglibose                         |    HIV edge pred:    0.03316
# Drug: vinblastine                       |    HIV edge pred:    0.03143
# Drug: miglitol                          |    HIV edge pred:    0.02961
# Drug: nan                               |    HIV edge pred:    0.02842
# Drug: L-Valine                          |    HIV edge pred:     0.0276
# Drug: methazolamide                     |    HIV edge pred:    0.02644
# Drug: N-Acetyl-D-glucosamine            |    HIV edge pred:    0.02566
# Drug: rifamycin                         |    HIV edge pred:    0.02499
# Drug: nan                               |    HIV edge pred:    0.02473
# Drug: felbamate                         |    HIV edge pred:    0.02409
# Drug: choline salicylate                |    HIV edge pred:    0.02261
# Drug: bevantolol                        |    HIV edge pred:    0.02177
# Drug: Theophylline                      |    HIV edge pred:    0.02175
# Drug: gabapentin-enacarbil              |    HIV edge pred:    0.02165
# Drug: nan                               |    HIV edge pred:    0.02121
# Drug: L-Histidine                       |    HIV edge pred:    0.01975
# Drug: Cobicistat                        |    HIV edge pred:    0.01967
# Drug: abacavir                          |    HIV edge pred:    0.01938
# Drug: coumarin                          |    HIV edge pred:    0.01837
# Drug: Oxacillin                         |    HIV edge pred:     0.0175
# Drug: cyclosporine                      |    HIV edge pred:    0.01708
# Drug: dextroamphetamine                 |    HIV edge pred:      0.017
# Drug: dyphylline                        |    HIV edge pred:    0.01611
# Drug: orlistat                          |    HIV edge pred:    0.01389
# Drug: Efonidipine                       |    HIV edge pred:    0.01354
# Drug: ergonovine                        |    HIV edge pred:    0.01338
# Drug: phenylephrine                     |    HIV edge pred:    0.01269
# Drug: triamterene                       |    HIV edge pred:    0.01269
# Drug: sildenafil                        |    HIV edge pred:    0.01247
# Drug: isometheptene-mucate              |    HIV edge pred:    0.01232
# Drug: Biotin                            |    HIV edge pred:    0.01183
# Drug: potassium chloride                |    HIV edge pred:     0.0116
# Drug: Tromethamine                      |    HIV edge pred:    0.01088
# Drug: Choline                           |    HIV edge pred:   0.009913
# Drug: cyanocobalamin                    |    HIV edge pred:   0.009639
# Drug: roflumilast                       |    HIV edge pred:   0.009542
# Drug: bleomycin                         |    HIV edge pred:   0.009526
# Drug: phentolamine                      |    HIV edge pred:   0.009171
# Drug: etilefrine                        |    HIV edge pred:   0.009164
# Drug: fosamprenavir                     |    HIV edge pred:   0.008519
# Drug: raltegravir                       |    HIV edge pred:   0.008519
# Drug: cabotegravir                      |    HIV edge pred:   0.008519
# Drug: tipranavir                        |    HIV edge pred:   0.008519
# Drug: atazanavir                        |    HIV edge pred:   0.008519
# Drug: darunavir                         |    HIV edge pred:   0.008519
# Drug: nevirapine                        |    HIV edge pred:   0.008519
# Drug: efavirenz                         |    HIV edge pred:   0.008519
# Drug: doravirine                        |    HIV edge pred:   0.008519
# Drug: lamivudine                        |    HIV edge pred:   0.008519
# Drug: emtricitabine                     |    HIV edge pred:   0.008519
# Drug: L-Lysine                          |    HIV edge pred:   0.008337
# Drug: fostamatinib                      |    HIV edge pred:   0.007658
# Drug: benzylpenicillin                  |    HIV edge pred:   0.007219
# Drug: isosorbide-mononitrate            |    HIV edge pred:   0.007139
# Drug: L-Ornithine                       |    HIV edge pred:    0.00643
# Drug: pentoxifylline                    |    HIV edge pred:   0.006075
# Drug: nan                               |    HIV edge pred:   0.005636
# Drug: L-Asparagine                      |    HIV edge pred:   0.005299
# Drug: homatropine                       |    HIV edge pred:   0.003205
# Drug: riociguat                         |    HIV edge pred:  0.0007827
# Drug: thioproperazine                   |    HIV edge pred:  6.262e-05
# Drug: clonidine                         |    HIV edge pred:  3.761e-05
# Drug: doxazosin                         |    HIV edge pred:  -0.000391
# Drug: trimethadione                     |    HIV edge pred: -0.0005565
# Drug: paramethadione                    |    HIV edge pred: -0.0005565
# Drug: phensuximide                      |    HIV edge pred: -0.0005565
# Drug: methsuximide                      |    HIV edge pred: -0.0005565
# Drug: hydralazine                       |    HIV edge pred:  -0.001013
# Drug: melatonin                         |    HIV edge pred:  -0.001597
# Drug: naphazoline                       |    HIV edge pred:  -0.002184
# Drug: colchicine                        |    HIV edge pred:  -0.002489
# Drug: terazosin                         |    HIV edge pred:  -0.003253
# Drug: nicergoline                       |    HIV edge pred:  -0.003269
# Drug: dexlansoprazole                   |    HIV edge pred:   -0.00338
# Drug: milnacipran                       |    HIV edge pred:  -0.003914
# Drug: zidovudine                        |    HIV edge pred:  -0.004043
# Drug: chloroquine                       |    HIV edge pred:  -0.004205
# Drug: L-Cysteine                        |    HIV edge pred:  -0.004209
# Drug: ademetionine                      |    HIV edge pred:  -0.004466
# Drug: ketotifen                         |    HIV edge pred:  -0.004625
# Drug: chlorpromazine                    |    HIV edge pred:  -0.004695
# Drug: Sertindole                        |    HIV edge pred:  -0.004866
# Drug: Hydroxocobalamin                  |    HIV edge pred:  -0.005058
# Drug: gabapentin                        |    HIV edge pred:  -0.005147
# Drug: etravirine                        |    HIV edge pred:  -0.006181
# Drug: isosorbide-dinitrate              |    HIV edge pred:  -0.006201
# Drug: apraclonidine                     |    HIV edge pred:  -0.007498
# Drug: apremilast                        |    HIV edge pred:  -0.007625
# Drug: carvedilol                        |    HIV edge pred:  -0.007772
# Drug: trapidil                          |    HIV edge pred:  -0.007789
# Drug: niacin                            |    HIV edge pred:  -0.007895
# Drug: nan                               |    HIV edge pred:  -0.007934
# Drug: ketoconazole                      |    HIV edge pred:   -0.00812
# Drug: aspirin                           |    HIV edge pred:  -0.008684
# Drug: acarbose                          |    HIV edge pred:   -0.00885
# Drug: tesamorelin                       |    HIV edge pred:  -0.009142
# Drug: flupentixol                       |    HIV edge pred:  -0.009262
# Drug: nedocromil                        |    HIV edge pred:  -0.009298
# Drug: epinastine                        |    HIV edge pred:  -0.009366
# Drug: pregabalin                        |    HIV edge pred:   -0.00941
# Drug: rifampin                          |    HIV edge pred:   -0.01036
# Drug: ethosuximide                      |    HIV edge pred:   -0.01041
# Drug: sargramostim                      |    HIV edge pred:   -0.01046
# Drug: Benzoic Acid                      |    HIV edge pred:   -0.01155
# Drug: irinotecan                        |    HIV edge pred:   -0.01177
# Drug: promazine                         |    HIV edge pred:   -0.01247
# Drug: esomeprazole                      |    HIV edge pred:   -0.01268
# Drug: resorcinol                        |    HIV edge pred:   -0.01358
# Drug: piribedil                         |    HIV edge pred:   -0.01394
# Drug: ampicillin                        |    HIV edge pred:   -0.01422
# Drug: dalfampridine                     |    HIV edge pred:    -0.0143
# Drug: ethoxzolamide                     |    HIV edge pred:   -0.01477
# Drug: magnesium carbonate               |    HIV edge pred:   -0.01528
# Drug: doxofylline                       |    HIV edge pred:   -0.01569
# Drug: terbinafine                       |    HIV edge pred:   -0.01588
# Drug: meclofenamic-acid                 |    HIV edge pred:   -0.01601
# Drug: Phenol                            |    HIV edge pred:   -0.01624
# Drug: zuclopenthixol                    |    HIV edge pred:   -0.01704
# Drug: bepridil                          |    HIV edge pred:    -0.0172
# Drug: nan                               |    HIV edge pred:   -0.01789
# Drug: nan                               |    HIV edge pred:   -0.01805
# Drug: orphenadrine                      |    HIV edge pred:   -0.01887
# Drug: nan                               |    HIV edge pred:   -0.01902
# Drug: nan                               |    HIV edge pred:   -0.01947
# Drug: cisplatin                         |    HIV edge pred:    -0.0201
# Drug: Pyruvic acid                      |    HIV edge pred:   -0.02017
# Drug: bumetanide                        |    HIV edge pred:   -0.02021
# Drug: enfuvirtide                       |    HIV edge pred:   -0.02067
# Drug: fostemsavir                       |    HIV edge pred:   -0.02067
# Drug: atomoxetine                       |    HIV edge pred:   -0.02105
# Drug: dipivefrine                       |    HIV edge pred:   -0.02105
# Drug: lenacapavir                       |    HIV edge pred:   -0.02143
# Drug: Ergoloid mesylate                 |    HIV edge pred:   -0.02152
# Drug: perospirone                       |    HIV edge pred:   -0.02162
# Drug: tamsulosin                        |    HIV edge pred:   -0.02221
# Drug: estramustine                      |    HIV edge pred:   -0.02222
# Drug: paliperidone                      |    HIV edge pred:   -0.02235
# Drug: chlorthalidone                    |    HIV edge pred:   -0.02251
# Drug: ixabepilone                       |    HIV edge pred:   -0.02277
# Drug: ibudilast                         |    HIV edge pred:   -0.02286
# Drug: zonisamide                        |    HIV edge pred:   -0.02287
# Drug: ibuprofen                         |    HIV edge pred:   -0.02302
# Drug: Phenobarbital                     |    HIV edge pred:   -0.02363
# Drug: ceftriaxone                       |    HIV edge pred:   -0.02404
# Drug: pirfenidone                       |    HIV edge pred:   -0.02429
# Drug: dipyridamole                      |    HIV edge pred:   -0.02437
# Drug: caffeine                          |    HIV edge pred:   -0.02451
# Drug: ephedrine                         |    HIV edge pred:   -0.02489
# Drug: iloperidone                       |    HIV edge pred:   -0.02516
# Drug: bortezomib                        |    HIV edge pred:   -0.02552
# Drug: Vitamin C                         |    HIV edge pred:   -0.02603
# Drug: prazosin                          |    HIV edge pred:   -0.02614
# Drug: tolazoline                        |    HIV edge pred:   -0.02627
# Drug: escitalopram                      |    HIV edge pred:   -0.02644
# Drug: nan                               |    HIV edge pred:   -0.02678
# Drug: vinorelbine                       |    HIV edge pred:   -0.02695
# Drug: Lactose                           |    HIV edge pred:     -0.027
# Drug: rabeprazole                       |    HIV edge pred:   -0.02709
# Drug: labetalol                         |    HIV edge pred:   -0.02746
# Drug: Moxisylyte                        |    HIV edge pred:   -0.02898
# Drug: trifluoperazine                   |    HIV edge pred:   -0.02904
# Drug: flunarizine                       |    HIV edge pred:   -0.02929
# Drug: dobutamine                        |    HIV edge pred:   -0.02952
# Drug: isoprenaline                      |    HIV edge pred:   -0.02963
# Drug: L-Arginine                        |    HIV edge pred:   -0.02987
# Drug: ibandronate                       |    HIV edge pred:   -0.02994
# Drug: Pyridoxal Phosphate               |    HIV edge pred:   -0.03093
# Drug: lomustine                         |    HIV edge pred:   -0.03096
# Drug: pipamperone                       |    HIV edge pred:   -0.03152
# Drug: amitriptyline                     |    HIV edge pred:   -0.03201
# Drug: laropiprant                       |    HIV edge pred:   -0.03211
# Drug: quercetin                         |    HIV edge pred:   -0.03212
# Drug: Glutathione                       |    HIV edge pred:   -0.03289
# Drug: amoxicillin                       |    HIV edge pred:   -0.03293
# Drug: retinol                           |    HIV edge pred:   -0.03297
# Drug: amlexanox                         |    HIV edge pred:    -0.0332
# Drug: nan                               |    HIV edge pred:   -0.03331
# Drug: Elotuzumab                        |    HIV edge pred:   -0.03338
# Drug: iloprost                          |    HIV edge pred:   -0.03416
# Drug: droperidol                        |    HIV edge pred:   -0.03465
# Drug: pantoprazole                      |    HIV edge pred:    -0.0349
# Drug: nicardipine                       |    HIV edge pred:   -0.03493
# Drug: pimozide                          |    HIV edge pred:   -0.03506
# Drug: topotecan                         |    HIV edge pred:   -0.03531
# Drug: Succinic acid                     |    HIV edge pred:   -0.03551
# Drug: cimetidine                        |    HIV edge pred:   -0.03557
# Drug: progesterone                      |    HIV edge pred:   -0.03595
# Drug: verapamil                         |    HIV edge pred:   -0.03664
# Drug: risperidone                       |    HIV edge pred:   -0.03676
# Drug: Amphetamine                       |    HIV edge pred:   -0.03715
# Drug: ibutilide                         |    HIV edge pred:   -0.03716
# Drug: Aranidipine                       |    HIV edge pred:   -0.03786
# Drug: selexipag                         |    HIV edge pred:   -0.03812
# Drug: Dinoprostone                      |    HIV edge pred:   -0.03843
# Drug: oxymetazoline                     |    HIV edge pred:   -0.03845
# Drug: Calcium Chloride                  |    HIV edge pred:    -0.0396
# Drug: trimipramine                      |    HIV edge pred:   -0.03997
# Drug: zinc                              |    HIV edge pred:   -0.04088
# Drug: miconazole                        |    HIV edge pred:   -0.04121
# Drug: L-Aspartic Acid                   |    HIV edge pred:   -0.04162
# Drug: dorzolamide                       |    HIV edge pred:   -0.04225
# Drug: L-Citrulline                      |    HIV edge pred:   -0.04237
# Drug: fenoldopam                        |    HIV edge pred:   -0.04296
# Drug: amiloride                         |    HIV edge pred:   -0.04309
# Drug: nan                               |    HIV edge pred:   -0.04309
# Drug: metaraminol                       |    HIV edge pred:   -0.04385
# Drug: tretinoin                         |    HIV edge pred:   -0.04399
# Drug: cefotaxime                        |    HIV edge pred:   -0.04437
# Drug: fingolimod                        |    HIV edge pred:   -0.04478
# Drug: levonordefrin                     |    HIV edge pred:   -0.04534
# Drug: brinzolamide                      |    HIV edge pred:   -0.04584
# Drug: maprotiline                       |    HIV edge pred:    -0.0464
# Drug: ibalizumab                        |    HIV edge pred:   -0.04644
# Drug: trazodone                         |    HIV edge pred:   -0.04693
# Drug: quinidine                         |    HIV edge pred:   -0.04735
# Drug: thioguanine                       |    HIV edge pred:    -0.0474
# Drug: aripiprazole                      |    HIV edge pred:   -0.04817
# Drug: imipramine                        |    HIV edge pred:    -0.0491
# Drug: pamidronate                       |    HIV edge pred:   -0.04956
# Drug: Isothipendyl                      |    HIV edge pred:   -0.04969
# Drug: test_drug                         |    HIV edge pred:   -0.05084
# Drug: epinephrine                       |    HIV edge pred:   -0.05113
# Drug: cabergoline                       |    HIV edge pred:   -0.05138
# Drug: bromocriptine                     |    HIV edge pred:   -0.05175
# Drug: felodipine                        |    HIV edge pred:   -0.05298
# Drug: Glycine                           |    HIV edge pred:   -0.05308
# Drug: carfilzomib                       |    HIV edge pred:    -0.0533
# Drug: nan                               |    HIV edge pred:   -0.05346
# Drug: lansoprazole                      |    HIV edge pred:   -0.05436
# Drug: lamotrigine                       |    HIV edge pred:   -0.05473
# Drug: fluconazole                       |    HIV edge pred:   -0.05491
# Drug: omeprazole                        |    HIV edge pred:   -0.05492
# Drug: tropicamide                       |    HIV edge pred:   -0.05583
# Drug: risedronate                       |    HIV edge pred:   -0.05586
# Drug: dosulepin                         |    HIV edge pred:    -0.0562
# Drug: nan                               |    HIV edge pred:   -0.05641
# Drug: spironolactone                    |    HIV edge pred:   -0.05694
# Drug: nan                               |    HIV edge pred:   -0.05719
# Drug: pizotifen                         |    HIV edge pred:   -0.05739
# Drug: levomepromazine                   |    HIV edge pred:    -0.0576
# Drug: menadione                         |    HIV edge pred:   -0.05807
# Drug: lesinurad                         |    HIV edge pred:    -0.0588
# Drug: Sodium stibogluconate             |    HIV edge pred:   -0.05904
# Drug: Adenosine monophosphate           |    HIV edge pred:   -0.05905
# Drug: Iron                              |    HIV edge pred:    -0.0596
# Drug: Nafarelin                         |    HIV edge pred:   -0.05965
# Drug: trimetazidine                     |    HIV edge pred:   -0.05979
# Drug: ergotamine                        |    HIV edge pred:    -0.0603
# Drug: cyproheptadine                    |    HIV edge pred:   -0.06053
# Drug: probenecid                        |    HIV edge pred:    -0.0606
# Drug: phenoxybenzamine                  |    HIV edge pred:   -0.06061
# Drug: asenapine                         |    HIV edge pred:   -0.06098
# Drug: tiagabine                         |    HIV edge pred:   -0.06159
# Drug: levetiracetam                     |    HIV edge pred:   -0.06193
# Drug: dantrolene                        |    HIV edge pred:   -0.06225
# Drug: desipramine                       |    HIV edge pred:   -0.06227
# Drug: nan                               |    HIV edge pred:   -0.06256
# Drug: maraviroc                         |    HIV edge pred:   -0.06269
# Drug: zoledronic-acid                   |    HIV edge pred:     -0.063
# Drug: pentamidine                       |    HIV edge pred:   -0.06337
# Drug: Aceprometazine                    |    HIV edge pred:   -0.06343
# Drug: tofogliflozin                     |    HIV edge pred:   -0.06356
# Drug: methocarbamol                     |    HIV edge pred:   -0.06456
# Drug: etoposide                         |    HIV edge pred:   -0.06456
# Drug: nan                               |    HIV edge pred:   -0.06581
# Drug: xylometazoline                    |    HIV edge pred:   -0.06595
# Drug: norepinephrine                    |    HIV edge pred:   -0.06626
# Drug: cyclopentolate                    |    HIV edge pred:    -0.0663
# Drug: levocabastine                     |    HIV edge pred:   -0.06776
# Drug: ziprasidone                       |    HIV edge pred:   -0.06877
# Drug: Aprotinin                         |    HIV edge pred:   -0.06887
# Drug: dronedarone                       |    HIV edge pred:   -0.06953
# Drug: olopatadine                       |    HIV edge pred:   -0.07022
# Drug: Secobarbital                      |    HIV edge pred:   -0.07033
# Drug: vincristine                       |    HIV edge pred:   -0.07039
# Drug: methoxamine                       |    HIV edge pred:   -0.07041
# Drug: lisuride                          |    HIV edge pred:    -0.0707
# Drug: DIHYDROERGOCORNINE                |    HIV edge pred:   -0.07207
# Drug: cinnarizine                       |    HIV edge pred:   -0.07224
# Drug: mycophenolate-mofetil             |    HIV edge pred:   -0.07253
# Drug: mycophenolic-acid                 |    HIV edge pred:   -0.07253
# Drug: Pergolide                         |    HIV edge pred:   -0.07264
# Drug: quetiapine                        |    HIV edge pred:   -0.07366
# Drug: mirtazapine                       |    HIV edge pred:   -0.07367
# Drug: Dehydroepiandrosterone            |    HIV edge pred:   -0.07392
# Drug: Ecothiopate                       |    HIV edge pred:   -0.07427
# Drug: doxepin                           |    HIV edge pred:   -0.07429
# Drug: Urokinase                         |    HIV edge pred:   -0.07438
# Drug: promethazine                      |    HIV edge pred:   -0.07442
# Drug: alendronate                       |    HIV edge pred:   -0.07536
# Drug: L-Phenylalanine                   |    HIV edge pred:   -0.07565
# Drug: mianserin                         |    HIV edge pred:   -0.07595
# Drug: droxidopa                         |    HIV edge pred:   -0.07604
# Drug: NADH                              |    HIV edge pred:   -0.07638
# Drug: loxapine                          |    HIV edge pred:   -0.07651
# Drug: homoharringtonine                 |    HIV edge pred:    -0.0767
# Drug: oxcarbazepine                     |    HIV edge pred:   -0.07728
# Drug: levocarnitine                     |    HIV edge pred:   -0.07742
# Drug: ramatroban                        |    HIV edge pred:   -0.07775
# Drug: diazepam                          |    HIV edge pred:   -0.07827
# Drug: Pentobarbital                     |    HIV edge pred:    -0.0783
# Drug: L-Isoleucine                      |    HIV edge pred:   -0.07833
# Drug: azelnidipine                      |    HIV edge pred:   -0.07881
# Drug: Eribulin                          |    HIV edge pred:   -0.07932
# Drug: botulinum toxin type B            |    HIV edge pred:   -0.07962
# Drug: capsaicin                         |    HIV edge pred:   -0.07985
# Drug: Adalimumab                        |    HIV edge pred:   -0.07993
# Drug: DIHYDROERGOCRISTINE               |    HIV edge pred:   -0.08012
# Drug: telbivudine                       |    HIV edge pred:   -0.08022
# Drug: nan                               |    HIV edge pred:   -0.08031
# Drug: nan                               |    HIV edge pred:   -0.08031
# Drug: sulfinpyrazone                    |    HIV edge pred:   -0.08083
# Drug: acamprosate                       |    HIV edge pred:   -0.08099
# Drug: clozapine                         |    HIV edge pred:   -0.08106
# Drug: vedolizumab                       |    HIV edge pred:   -0.08114
# Drug: Alprazolam                        |    HIV edge pred:   -0.08168
# Drug: chloropyramine                    |    HIV edge pred:   -0.08182
# Drug: eperisone                         |    HIV edge pred:   -0.08183
# Drug: propylhexedrine                   |    HIV edge pred:    -0.0819
# Drug: doripenem                         |    HIV edge pred:   -0.08201
# Drug: propiomazine                      |    HIV edge pred:    -0.0821
# Drug: ibrutinib                         |    HIV edge pred:   -0.08261
# Drug: ivabradine                        |    HIV edge pred:   -0.08296
# Drug: cladribine                        |    HIV edge pred:   -0.08371
# Drug: propiverine                       |    HIV edge pred:   -0.08388
# Drug: dactinomycin                      |    HIV edge pred:   -0.08429
# Drug: nan                               |    HIV edge pred:   -0.08448
# Drug: nan                               |    HIV edge pred:   -0.08472
# Drug: Abciximab                         |    HIV edge pred:   -0.08483
# Drug: amsacrine                         |    HIV edge pred:   -0.08492
# Drug: mephentermine                     |    HIV edge pred:   -0.08501
# Drug: buphenine                         |    HIV edge pred:   -0.08511
# Drug: teniposide                        |    HIV edge pred:   -0.08539
# Drug: isopropamide-iodide               |    HIV edge pred:   -0.08584
# Drug: nan                               |    HIV edge pred:   -0.08669
# Drug: ezetimibe                         |    HIV edge pred:     -0.087
# Drug: Hesperetin                        |    HIV edge pred:   -0.08753
# Drug: gemcitabine                       |    HIV edge pred:   -0.08778
# Drug: Glucagon recombinant              |    HIV edge pred:   -0.08779
# Drug: palivizumab                       |    HIV edge pred:   -0.08816
# Drug: nortriptyline                     |    HIV edge pred:   -0.08865
# Drug: nan                               |    HIV edge pred:   -0.08895
# Drug: olaparib                          |    HIV edge pred:   -0.08923
# Drug: deoxycholic-acid                  |    HIV edge pred:   -0.08955
# Drug: nan                               |    HIV edge pred:   -0.08968
# Drug: Diethylstilbestrol                |    HIV edge pred:   -0.08979
# Drug: Nitrazepam                        |    HIV edge pred:   -0.09042
# Drug: dexrazoxane                       |    HIV edge pred:   -0.09045
# Drug: Histrelin                         |    HIV edge pred:   -0.09072
# Drug: eszopiclone                       |    HIV edge pred:   -0.09114
# Drug: olanzapine                        |    HIV edge pred:   -0.09127
# Drug: folic-acid                        |    HIV edge pred:   -0.09128
# Drug: tolvaptan                         |    HIV edge pred:   -0.09145
# Drug: bosutinib                         |    HIV edge pred:   -0.09152
# Drug: fluspirilene                      |    HIV edge pred:   -0.09167
# Drug: zafirlukast                       |    HIV edge pred:   -0.09202
# Drug: pemirolast                        |    HIV edge pred:   -0.09222
# Drug: nitisinone                        |    HIV edge pred:   -0.09224
# Drug: dasatinib                         |    HIV edge pred:   -0.09238
# Drug: sapropterin                       |    HIV edge pred:   -0.09254
# Drug: nan                               |    HIV edge pred:    -0.0934
# Drug: daunorubicin                      |    HIV edge pred:   -0.09403
# Drug: Romiplostim                       |    HIV edge pred:   -0.09425
# Drug: bilastine                         |    HIV edge pred:   -0.09444
# Drug: Cetuximab                         |    HIV edge pred:   -0.09451
# Drug: methacholine                      |    HIV edge pred:   -0.09458
# Drug: Pramlintide                       |    HIV edge pred:   -0.09464
# Drug: levomenthol                       |    HIV edge pred:   -0.09482
# Drug: gonadorelin                       |    HIV edge pred:     -0.095
# Drug: bepotastine                       |    HIV edge pred:   -0.09514
# Drug: alcaftadine                       |    HIV edge pred:   -0.09566
# Drug: fesoterodine                      |    HIV edge pred:   -0.09584
# Drug: tolterodine                       |    HIV edge pred:   -0.09584
# Drug: solifenacin-succinate             |    HIV edge pred:   -0.09584
# Drug: darifenacin                       |    HIV edge pred:   -0.09584
# Drug: SUCROSE                           |    HIV edge pred:   -0.09589
# Drug: ocrelizumab                       |    HIV edge pred:   -0.09595
# Drug: Felypressin                       |    HIV edge pred:   -0.09595
# Drug: vandetanib                        |    HIV edge pred:   -0.09615
# Drug: DUPILUMAB                         |    HIV edge pred:   -0.09621
# Drug: Etanercept                        |    HIV edge pred:   -0.09665
# Drug: hydroxyzine                       |    HIV edge pred:   -0.09666
# Drug: tocofersolan                      |    HIV edge pred:   -0.09667
# Drug: estradiol cypionate               |    HIV edge pred:   -0.09674
# Drug: Defibrotide                       |    HIV edge pred:   -0.09679
# Drug: linezolid                         |    HIV edge pred:   -0.09683
# Drug: topiramate                        |    HIV edge pred:   -0.09689
# Drug: ripasudil                         |    HIV edge pred:   -0.09705
# Drug: Dexchlorpheniramine maleate       |    HIV edge pred:   -0.09713
# Drug: nan                               |    HIV edge pred:    -0.0973
# Drug: Nitric Oxide                      |    HIV edge pred:   -0.09756
# Drug: Antithrombin III                  |    HIV edge pred:   -0.09766
# Drug: testosterone cypionate            |    HIV edge pred:   -0.09772
# Drug: amlodipine                        |    HIV edge pred:   -0.09773
# Drug: taurine                           |    HIV edge pred:    -0.0978
# Drug: dimenhydrinate                    |    HIV edge pred:   -0.09793
# Drug: azelastine                        |    HIV edge pred:   -0.09807
# Drug: Adenine                           |    HIV edge pred:   -0.09819
# Drug: emedastine                        |    HIV edge pred:    -0.0983
# Drug: vernakalant                       |    HIV edge pred:    -0.0985
# Drug: adapalene                         |    HIV edge pred:   -0.09858
# Drug: isocarboxazid                     |    HIV edge pred:   -0.09879
# Drug: furosemide                        |    HIV edge pred:   -0.09883
# Drug: epirubicin                        |    HIV edge pred:   -0.09884
# Drug: butabarbital                      |    HIV edge pred:   -0.09944
# Drug: teriflunomide                     |    HIV edge pred:   -0.09962
# Drug: atropine                          |    HIV edge pred:   -0.09989
# Drug: triptorelin                       |    HIV edge pred:   -0.09999
# Drug: phenelzine                        |    HIV edge pred:    -0.1001
# Drug: cefadroxil                        |    HIV edge pred:    -0.1002
# Drug: Cilastatin                        |    HIV edge pred:    -0.1002
# Drug: Sermorelin                        |    HIV edge pred:    -0.1004
# Drug: primidone                         |    HIV edge pred:    -0.1006
# Drug: atovaquone                        |    HIV edge pred:    -0.1008
# Drug: etidronic-acid                    |    HIV edge pred:     -0.101
# Drug: itraconazole                      |    HIV edge pred:    -0.1011
# Drug: efinaconazole                     |    HIV edge pred:    -0.1011
# Drug: carbinoxamine                     |    HIV edge pred:    -0.1011
# Drug: Talbutal                          |    HIV edge pred:    -0.1013
# Drug: stiripentol                       |    HIV edge pred:    -0.1013
# Drug: nan                               |    HIV edge pred:    -0.1015
# Drug: nan                               |    HIV edge pred:    -0.1018
# Drug: streptozotocin                    |    HIV edge pred:    -0.1018
# Drug: nan                               |    HIV edge pred:    -0.1021
# Drug: Thalidomide                       |    HIV edge pred:    -0.1023
# Drug: mesalazine                        |    HIV edge pred:    -0.1025
# Drug: antazoline                        |    HIV edge pred:    -0.1029
# Drug: phytonadione                      |    HIV edge pred:    -0.1029
# Drug: conivaptan                        |    HIV edge pred:    -0.1032
# Drug: nan                               |    HIV edge pred:    -0.1033
# Drug: epoprostenol                      |    HIV edge pred:    -0.1034
# Drug: PEGINESATIDE                      |    HIV edge pred:    -0.1035
# Drug: METHOXY POLYETHYLENE GLYCOL-EPOETIN BETA    |    HIV edge pred:    -0.1035
# Drug: Erythropoietin                    |    HIV edge pred:    -0.1035
# Drug: Darbepoetin alfa                  |    HIV edge pred:    -0.1035
# Drug: tropisetron                       |    HIV edge pred:    -0.1036
# Drug: moclobemide                       |    HIV edge pred:    -0.1037
# Drug: tryptophan                        |    HIV edge pred:    -0.1038
# Drug: nan                               |    HIV edge pred:    -0.1044
# Drug: cevimeline                        |    HIV edge pred:    -0.1046
# Drug: ribavirin                         |    HIV edge pred:    -0.1047
# Drug: Dexbrompheniramine                |    HIV edge pred:    -0.1047
# Drug: amoxapine                         |    HIV edge pred:    -0.1049
# Drug: disopyramide                      |    HIV edge pred:     -0.105
# Drug: docetaxel                         |    HIV edge pred:     -0.105
# Drug: prucalopride                      |    HIV edge pred:    -0.1051
# Drug: Kappadione                        |    HIV edge pred:    -0.1055
# Drug: tridihexethyl                     |    HIV edge pred:    -0.1055
# Drug: Mequitazine                       |    HIV edge pred:    -0.1058
# Drug: levocetirizine                    |    HIV edge pred:    -0.1058
# Drug: carbetocin                        |    HIV edge pred:    -0.1061
# Drug: CHROMIUM                          |    HIV edge pred:    -0.1063
# Drug: Chlordiazepoxide                  |    HIV edge pred:    -0.1063
# Drug: pilocarpine                       |    HIV edge pred:    -0.1066
# Drug: Zopiclone                         |    HIV edge pred:    -0.1069
# Drug: nan                               |    HIV edge pred:     -0.107
# Drug: clonazepam                        |    HIV edge pred:    -0.1071
# Drug: aminosalicylate                   |    HIV edge pred:    -0.1071
# Drug: pargyline                         |    HIV edge pred:    -0.1071
# Drug: doxorubicin                       |    HIV edge pred:    -0.1072
# Drug: tadalafil                         |    HIV edge pred:    -0.1073
# Drug: clobazam                          |    HIV edge pred:    -0.1073
# Drug: eplerenone                        |    HIV edge pred:    -0.1074
# Drug: clomifene                         |    HIV edge pred:    -0.1076
# Drug: sarilumab                         |    HIV edge pred:    -0.1076
# Drug: potassium-canrenoate              |    HIV edge pred:    -0.1076
# Drug: clofedanol                        |    HIV edge pred:    -0.1076
# Drug: gemfibrozil                       |    HIV edge pred:    -0.1077
# Drug: zolmitriptan                      |    HIV edge pred:    -0.1078
# Drug: naratriptan                       |    HIV edge pred:    -0.1078
# Drug: rizatriptan                       |    HIV edge pred:    -0.1078
# Drug: carisoprodol                      |    HIV edge pred:    -0.1082
# Drug: carmustine                        |    HIV edge pred:    -0.1085
# Drug: nan                               |    HIV edge pred:    -0.1086
# Drug: benralizumab                      |    HIV edge pred:    -0.1087
# Drug: niflumic-acid                     |    HIV edge pred:    -0.1087
# Drug: NAFAMOSTAT                        |    HIV edge pred:    -0.1089
# Drug: carbidopa                         |    HIV edge pred:    -0.1089
# Drug: triprolidine                      |    HIV edge pred:    -0.1091
# Drug: toloxatone                        |    HIV edge pred:    -0.1094
# Drug: Gemtuzumab ozogamicin             |    HIV edge pred:    -0.1096
# Drug: indomethacin                      |    HIV edge pred:    -0.1097
# Drug: ecabet                            |    HIV edge pred:    -0.1099
# Drug: tamoxifen                         |    HIV edge pred:    -0.1099
# Drug: serotonin                         |    HIV edge pred:      -0.11
# Drug: Aminophylline                     |    HIV edge pred:      -0.11
# Drug: demecarium                        |    HIV edge pred:    -0.1105
# Drug: regadenoson                       |    HIV edge pred:    -0.1107
# Drug: insulin human                     |    HIV edge pred:    -0.1108
# Drug: phenytoin                         |    HIV edge pred:    -0.1109
# Drug: ethinamate                        |    HIV edge pred:    -0.1112
# Drug: Glycerin                          |    HIV edge pred:    -0.1112
# Drug: palonosetron                      |    HIV edge pred:    -0.1113
# Drug: granisetron                       |    HIV edge pred:    -0.1113
# Drug: dolasetron                        |    HIV edge pred:    -0.1113
# Drug: nan                               |    HIV edge pred:    -0.1113
# Drug: tiotropium                        |    HIV edge pred:    -0.1114
# Drug: nan                               |    HIV edge pred:    -0.1116
# Drug: diclofenamide                     |    HIV edge pred:    -0.1119
# Drug: Methdilazine                      |    HIV edge pred:     -0.112
# Drug: metronidazole                     |    HIV edge pred:     -0.112
# Drug: safinamide                        |    HIV edge pred:     -0.112
# Drug: raloxifene                        |    HIV edge pred:    -0.1121
# Drug: Clorazepate                       |    HIV edge pred:    -0.1121
# Drug: isotretinoin                      |    HIV edge pred:    -0.1122
# Drug: deslanoside                       |    HIV edge pred:    -0.1124
# Drug: hydroxyurea                       |    HIV edge pred:    -0.1125
# Drug: Butethal                          |    HIV edge pred:     -0.113
# Drug: Magnesium Sulfate                 |    HIV edge pred:    -0.1132
# Drug: sulindac                          |    HIV edge pred:    -0.1133
# Drug: tranilast                         |    HIV edge pred:    -0.1133
# Drug: Omega-3-carboxylic acids          |    HIV edge pred:    -0.1134
# Drug: tubocurarine                      |    HIV edge pred:    -0.1137
# Drug: perhexiline                       |    HIV edge pred:    -0.1139
# Drug: meprobamate                       |    HIV edge pred:    -0.1139
# Drug: Trimeprazine                      |    HIV edge pred:    -0.1141
# Drug: Methamphetamine                   |    HIV edge pred:    -0.1142
# Drug: L-Serine                          |    HIV edge pred:    -0.1144
# Drug: estradiol                         |    HIV edge pred:    -0.1145
# Drug: carbamazepine                     |    HIV edge pred:    -0.1145
# Drug: zolpidem                          |    HIV edge pred:    -0.1148
# Drug: mefenamic-acid                    |    HIV edge pred:     -0.115
# Drug: Sodium Tetradecyl Sulfate         |    HIV edge pred:    -0.1152
# Drug: nan                               |    HIV edge pred:    -0.1152
# Drug: methyprylon                       |    HIV edge pred:    -0.1152
# Drug: Glutethimide                      |    HIV edge pred:    -0.1152
# Drug: Ethchlorvynol                     |    HIV edge pred:    -0.1152
# Drug: mercaptopurine                    |    HIV edge pred:    -0.1154
# Drug: alefacept                         |    HIV edge pred:    -0.1154
# Drug: nifedipine                        |    HIV edge pred:    -0.1155
# Drug: Treprostinil                      |    HIV edge pred:    -0.1156
# Drug: Halazepam                         |    HIV edge pred:    -0.1156
# Drug: adenosine                         |    HIV edge pred:    -0.1159
# Drug: efalizumab                        |    HIV edge pred:    -0.1162
# Drug: yohimbine                         |    HIV edge pred:    -0.1164
# Drug: tetrabenazine                     |    HIV edge pred:    -0.1164
# Drug: trastuzumab                       |    HIV edge pred:    -0.1166
# Drug: molsidomine                       |    HIV edge pred:    -0.1166
# Drug: lidocaine                         |    HIV edge pred:    -0.1168
# Drug: oxybutynin                        |    HIV edge pred:    -0.1168
# Drug: Triazolam                         |    HIV edge pred:    -0.1169
# Drug: quazepam                          |    HIV edge pred:    -0.1169
# Drug: Temazepam                         |    HIV edge pred:    -0.1169
# Drug: Flurazepam                        |    HIV edge pred:    -0.1169
# Drug: tazarotene                        |    HIV edge pred:    -0.1171
# Drug: tripelennamine                    |    HIV edge pred:    -0.1171
# Drug: vigabatrin                        |    HIV edge pred:    -0.1171
# Drug: azatadine                         |    HIV edge pred:    -0.1171
# Drug: fexofenadine                      |    HIV edge pred:    -0.1173
# Drug: lubiprostone                      |    HIV edge pred:    -0.1175
# Drug: isoflurophate                     |    HIV edge pred:    -0.1178
# Drug: scopolamine                       |    HIV edge pred:    -0.1178
# Drug: rimexolone                        |    HIV edge pred:     -0.118
# Drug: selegiline                        |    HIV edge pred:    -0.1182
# Drug: nan                               |    HIV edge pred:    -0.1183
# Drug: sumatriptan                       |    HIV edge pred:    -0.1184
# Drug: leuprolide                        |    HIV edge pred:    -0.1185
# Drug: nan                               |    HIV edge pred:    -0.1186
# Drug: pioglitazone                      |    HIV edge pred:    -0.1187
# Drug: eletriptan                        |    HIV edge pred:    -0.1187
# Drug: nan                               |    HIV edge pred:    -0.1188
# Drug: sulfasalazine                     |    HIV edge pred:    -0.1189
# Drug: phenacemide                       |    HIV edge pred:    -0.1192
# Drug: zotepine                          |    HIV edge pred:    -0.1194
# Drug: nan                               |    HIV edge pred:    -0.1194
# Drug: phenindamine                      |    HIV edge pred:    -0.1194
# Drug: mepyramine                        |    HIV edge pred:    -0.1196
# Drug: Terfenadine                       |    HIV edge pred:    -0.1201
# Drug: clofarabine                       |    HIV edge pred:    -0.1202
# Drug: testosterone                      |    HIV edge pred:    -0.1205
# Drug: thiopental                        |    HIV edge pred:    -0.1208
# Drug: mephenytoin                       |    HIV edge pred:    -0.1208
# Drug: metharbital                       |    HIV edge pred:    -0.1209
# Drug: Rituximab                         |    HIV edge pred:     -0.121
# Drug: tranylcypromine                   |    HIV edge pred:    -0.1211
# Drug: rufinamide                        |    HIV edge pred:    -0.1211
# Drug: setiptiline                       |    HIV edge pred:    -0.1211
# Drug: Natalizumab                       |    HIV edge pred:    -0.1212
# Drug: fotemustine                       |    HIV edge pred:    -0.1213
# Drug: dihydroergotamine                 |    HIV edge pred:    -0.1214
# Drug: Midazolam                         |    HIV edge pred:    -0.1215
# Drug: brivaracetam                      |    HIV edge pred:    -0.1216
# Drug: Prazepam                          |    HIV edge pred:    -0.1217
# Drug: thiothixene                       |    HIV edge pred:    -0.1219
# Drug: ipratropium                       |    HIV edge pred:    -0.1219
# Drug: lorazepam                         |    HIV edge pred:     -0.122
# Drug: thonzylamine                      |    HIV edge pred:     -0.122
# Drug: ranolazine                        |    HIV edge pred:     -0.122
# Drug: bethanechol                       |    HIV edge pred:    -0.1222
# Drug: thiocolchicoside                  |    HIV edge pred:    -0.1223
# Drug: dihydrotestosterone               |    HIV edge pred:    -0.1228
# Drug: lacosamide                        |    HIV edge pred:    -0.1229
# Drug: benserazide                       |    HIV edge pred:     -0.123
# Drug: aclidinium                        |    HIV edge pred:    -0.1233
# Drug: umeclidinium                      |    HIV edge pred:    -0.1233
# Drug: Theobromine                       |    HIV edge pred:    -0.1234
# Drug: clemastine                        |    HIV edge pred:    -0.1234
# Drug: prednisolone                      |    HIV edge pred:    -0.1234
# Drug: oxazepam                          |    HIV edge pred:    -0.1236
# Drug: nandrolone                        |    HIV edge pred:    -0.1239
# Drug: benzthiazide                      |    HIV edge pred:    -0.1243
# Drug: barbital                          |    HIV edge pred:    -0.1244
# Drug: papaverine                        |    HIV edge pred:    -0.1247
# Drug: hyoscyamine                       |    HIV edge pred:    -0.1248
# Drug: dabrafenib                        |    HIV edge pred:     -0.125
# Drug: Tositumomab                       |    HIV edge pred:    -0.1252
# Drug: Abatacept                         |    HIV edge pred:    -0.1253
# Drug: nintedanib                        |    HIV edge pred:    -0.1253
# Drug: paclitaxel                        |    HIV edge pred:    -0.1253
# Drug: Camphor                           |    HIV edge pred:    -0.1254
# Drug: anisindione                       |    HIV edge pred:    -0.1255
# Drug: perampanel                        |    HIV edge pred:    -0.1258
# Drug: Valproic Acid                     |    HIV edge pred:    -0.1259
# Drug: disulfiram                        |    HIV edge pred:    -0.1259
# Drug: obinutuzumab                      |    HIV edge pred:    -0.1261
# Drug: nan                               |    HIV edge pred:    -0.1262
# Drug: etizolam                          |    HIV edge pred:    -0.1263
# Drug: ethotoin                          |    HIV edge pred:    -0.1264
# Drug: procyclidine                      |    HIV edge pred:    -0.1264
# Drug: chlorprothixene                   |    HIV edge pred:    -0.1264
# Drug: Ibritumomab tiuxetan              |    HIV edge pred:    -0.1269
# Drug: diacerein                         |    HIV edge pred:     -0.127
# Drug: trihexyphenidyl                   |    HIV edge pred:    -0.1271
# Drug: Peginterferon alfa-2a             |    HIV edge pred:    -0.1272
# Drug: Phenazopyridine                   |    HIV edge pred:    -0.1273
# Drug: atosiban                          |    HIV edge pred:    -0.1273
# Drug: azathioprine                      |    HIV edge pred:    -0.1273
# Drug: nan                               |    HIV edge pred:    -0.1275
# Drug: cysteamine                        |    HIV edge pred:    -0.1275
# Drug: Desmopressin                      |    HIV edge pred:    -0.1276
# Drug: Benzphetamine                     |    HIV edge pred:    -0.1277
# Drug: nan                               |    HIV edge pred:    -0.1278
# Drug: MOROCTOCOG ALFA                   |    HIV edge pred:    -0.1278
# Drug: zaleplon                          |    HIV edge pred:     -0.128
# Drug: etifoxine                         |    HIV edge pred:     -0.128
# Drug: L-Glutamic Acid                   |    HIV edge pred:    -0.1283
# Drug: Bromodiphenhydramine              |    HIV edge pred:    -0.1283
# Drug: chlorcyclizine                    |    HIV edge pred:    -0.1284
# Drug: Carboprost Tromethamine           |    HIV edge pred:    -0.1287
# Drug: clodronic-acid                    |    HIV edge pred:    -0.1287
# Drug: L-Cystine                         |    HIV edge pred:    -0.1288
# Drug: belinostat                        |    HIV edge pred:    -0.1288
# Drug: eslicarbazepine-acetate           |    HIV edge pred:    -0.1288
# Drug: insulin, neutral                  |    HIV edge pred:    -0.1289
# Drug: leflunomide                       |    HIV edge pred:    -0.1289
# Drug: Sulodexide                        |    HIV edge pred:     -0.129
# Drug: desloratadine                     |    HIV edge pred:    -0.1298
# Drug: cetirizine                        |    HIV edge pred:    -0.1298
# ...
# DZ: Hemorrhagic Disorders             |    HIV edge pred:     0.7111
# DZ: Diabetes Mellitus, Insulin-Dependent    |    HIV edge pred:      0.711
# DZ: urinary retention                 |    HIV edge pred:      0.711
# DZ: Ovarian Failure, Premature        |    HIV edge pred:      0.711
# DZ: Osteitis Deformans                |    HIV edge pred:      0.711
# DZ: Hereditary C1 esterase inhibitor deficiency - deficient factor    |    HIV edge pred:     0.7109
# DZ: Turner Syndrome                   |    HIV edge pred:     0.7109
# DZ: Factor Xiii Deficiency            |    HIV edge pred:     0.7109
# DZ: Diabetes Insipidus                |    HIV edge pred:     0.7108
# DZ: Atypical Absence Seizure          |    HIV edge pred:     0.7108
# DZ: diabetic nephropathy              |    HIV edge pred:     0.7108
# DZ: Hashimoto Disease                 |    HIV edge pred:     0.7107
# DZ: Iridocyclitis                     |    HIV edge pred:     0.7107
# DZ: Ventricular Dysfunction, Left     |    HIV edge pred:     0.7106
# DZ: Stargardt's disease               |    HIV edge pred:     0.7106
# DZ: Hyperlipoproteinemia Type Iib     |    HIV edge pred:     0.7105
# DZ: cystinuria                        |    HIV edge pred:     0.7105
# DZ: Hyperlipoproteinemia Type Iii     |    HIV edge pred:     0.7104
# DZ: arteriosclerosis                  |    HIV edge pred:     0.7104
# DZ: Brain Edema                       |    HIV edge pred:     0.7103
# DZ: Keloid                            |    HIV edge pred:     0.7103
# DZ: Alcohol Withdrawal Acute          |    HIV edge pred:     0.7103
# DZ: Keratitis                         |    HIV edge pred:     0.7103
# DZ: Encephalitis                      |    HIV edge pred:     0.7102
# DZ: acute intermittent porphyria (AIP)    |    HIV edge pred:     0.7102
# DZ: Fibrosarcoma                      |    HIV edge pred:     0.7102
# DZ: Male Infertility                  |    HIV edge pred:     0.7101
# DZ: Delayed Puberty                   |    HIV edge pred:     0.7101
# DZ: Chronic Obstructive Airway Disease    |    HIV edge pred:     0.7101
# DZ: Malignant Tumor Of Colon          |    HIV edge pred:     0.7101
# DZ: Microalbuminuria                  |    HIV edge pred:     0.7101
# DZ: Thromboembolism                   |    HIV edge pred:     0.7101
# DZ: Disorder of eye                   |    HIV edge pred:       0.71
# DZ: Facial Dermatoses                 |    HIV edge pred:       0.71
# DZ: Infantile Spasms                  |    HIV edge pred:       0.71
# DZ: duchenne muscular dystrophy (DMD)    |    HIV edge pred:     0.7099
# DZ: acute lung injury                 |    HIV edge pred:     0.7099
# DZ: Epilepsies, Myoclonic             |    HIV edge pred:     0.7099
# DZ: medulloblastoma                   |    HIV edge pred:     0.7098
# DZ: Movement Disorders                |    HIV edge pred:     0.7098
# DZ: dystonia                          |    HIV edge pred:     0.7097
# DZ: Bartter Disease                   |    HIV edge pred:     0.7097
# DZ: Leukocytosis                      |    HIV edge pred:     0.7097
# DZ: Polycystic Ovary Syndrome         |    HIV edge pred:     0.7097
# DZ: Anemia, Diamond-Blackfan          |    HIV edge pred:     0.7096
# DZ: periodontitis                     |    HIV edge pred:     0.7096
# DZ: Ovarian Adenocarcinoma            |    HIV edge pred:     0.7096
# DZ: Gaucher Disease, Type 1           |    HIV edge pred:     0.7095
# DZ: Anxiety Disorders                 |    HIV edge pred:     0.7095
# DZ: Hypermagnesemia                   |    HIV edge pred:     0.7095
# DZ: dermatofibrosarcoma protuberans (DFSP)    |    HIV edge pred:     0.7095
# DZ: Chorea                            |    HIV edge pred:     0.7095
# DZ: Hidradenitis Suppurativa          |    HIV edge pred:     0.7094
# DZ: Diabetic Retinopathy              |    HIV edge pred:     0.7094
# DZ: anorexia                          |    HIV edge pred:     0.7094
# DZ: nystagmus                         |    HIV edge pred:     0.7093
# DZ: Mastocytosis                      |    HIV edge pred:     0.7093
# DZ: kidney stones                     |    HIV edge pred:     0.7093
# DZ: Acute Myeloid Leukemia, M1        |    HIV edge pred:     0.7093
# DZ: Skin Diseases, Bacterial          |    HIV edge pred:     0.7092
# DZ: Uveitis                           |    HIV edge pred:     0.7092
# DZ: Venous Thromboembolism            |    HIV edge pred:     0.7092
# DZ: Ehlers-Danlos syndrome (EDS)      |    HIV edge pred:     0.7092
# DZ: cavities                          |    HIV edge pred:     0.7091
# DZ: Polycystic Kidney, Autosomal Dominant    |    HIV edge pred:     0.7091
# DZ: Hemolysis (Disorder)              |    HIV edge pred:     0.7091
# DZ: Uremia                            |    HIV edge pred:      0.709
# DZ: gingivitis                        |    HIV edge pred:      0.709
# DZ: Complex Partial Seizures          |    HIV edge pred:     0.7089
# DZ: Secondary Parkinson Disease       |    HIV edge pred:     0.7089
# DZ: Corneal Ulcer                     |    HIV edge pred:     0.7089
# DZ: Coronary Arteriosclerosis         |    HIV edge pred:     0.7089
# DZ: Renal Hypertension                |    HIV edge pred:     0.7089
# DZ: hypercalcemia                     |    HIV edge pred:     0.7089
# DZ: Dermatitis, Allergic Contact      |    HIV edge pred:     0.7089
# DZ: hyponatremia                      |    HIV edge pred:     0.7088
# DZ: Esophagitis                       |    HIV edge pred:     0.7088
# DZ: amblyopia                         |    HIV edge pred:     0.7088
# DZ: Vitreous Hemorrhage               |    HIV edge pred:     0.7087
# DZ: Nasal Inflammation                |    HIV edge pred:     0.7087
# DZ: Ischemic Stroke                   |    HIV edge pred:     0.7087
# DZ: Primary Hypogonadism              |    HIV edge pred:     0.7087
# DZ: Pseudohypoparathyroidism          |    HIV edge pred:     0.7087
# DZ: Bronchial Hyperreactivity         |    HIV edge pred:     0.7087
# DZ: Toxic Multinodular Goiter         |    HIV edge pred:     0.7086
# DZ: Arterial Thrombosis               |    HIV edge pred:     0.7086
# DZ: iron overload                     |    HIV edge pred:     0.7086
# DZ: Alopecia                          |    HIV edge pred:     0.7085
# DZ: Mucocutaneous Lymph Node Syndrome    |    HIV edge pred:     0.7085
# DZ: Metabolic Syndrome X              |    HIV edge pred:     0.7085
# DZ: ependymoma                        |    HIV edge pred:     0.7085
# DZ: Grave's disease                   |    HIV edge pred:     0.7085
# DZ: acute coronary syndrome (ACS)     |    HIV edge pred:     0.7084
# DZ: Stomatitis                        |    HIV edge pred:     0.7084
# DZ: lymphangioleiomyomatosis          |    HIV edge pred:     0.7083
# DZ: Age Related Macular Degeneration    |    HIV edge pred:     0.7083
# DZ: gastroesophageal reflux disease (GERD)    |    HIV edge pred:     0.7083
# DZ: Adenocarcinoma                    |    HIV edge pred:     0.7083
# DZ: Orchitis                          |    HIV edge pred:     0.7083
# DZ: Kidney Failure                    |    HIV edge pred:     0.7083
# DZ: Impaired Glucose Tolerance        |    HIV edge pred:     0.7082
# DZ: Cryptorchidism                    |    HIV edge pred:     0.7082
# DZ: Irregular Periods                 |    HIV edge pred:     0.7081
# DZ: Zollinger-Ellison syndrome        |    HIV edge pred:     0.7081
# DZ: Deficiency of mevalonate kinase    |    HIV edge pred:      0.708
# DZ: Adenomatous Polyposis Coli        |    HIV edge pred:      0.708
# DZ: Hemochromatosis                   |    HIV edge pred:      0.708
# DZ: pneumonia                         |    HIV edge pred:      0.708
# DZ: TNF receptor-associated periodic fever syndrome (TRAPS)    |    HIV edge pred:      0.708
# DZ: Ectopic Pregnancy                 |    HIV edge pred:     0.7079
# DZ: Niemann-Pick Disease, Type C      |    HIV edge pred:     0.7079
# DZ: Fanconi Syndrome                  |    HIV edge pred:     0.7078
# DZ: Nasal Polyps                      |    HIV edge pred:     0.7078
# DZ: hydatidiform mole                 |    HIV edge pred:     0.7078
# DZ: rickets                           |    HIV edge pred:     0.7077
# DZ: Female Hypogonadism Syndrome      |    HIV edge pred:     0.7077
# DZ: Hematologic Neoplasms             |    HIV edge pred:     0.7077
# DZ: Erythropoietic Protoporphyria     |    HIV edge pred:     0.7077
# DZ: Esotropia                         |    HIV edge pred:     0.7077
# DZ: Refractory Anaemia With Excess Blasts    |    HIV edge pred:     0.7077
# DZ: Thrombasthenia                    |    HIV edge pred:     0.7077
# DZ: Rickettsia Infections             |    HIV edge pred:     0.7076
# DZ: EPILEPSY, PYRIDOXINE-DEPENDENT    |    HIV edge pred:     0.7076
# DZ: Pityriasis Rubra Pilaris          |    HIV edge pred:     0.7076
# DZ: Parathyroid Gland Adenocarcinoma    |    HIV edge pred:     0.7076
# DZ: Cholesterol Gallstones            |    HIV edge pred:     0.7076
# DZ: Hypocupremia                      |    HIV edge pred:     0.7075
# DZ: mastitis                          |    HIV edge pred:     0.7075
# DZ: Hypertrophic Cardiomyopathy       |    HIV edge pred:     0.7075
# DZ: Supraventricular arrhythmia       |    HIV edge pred:     0.7075
# DZ: Tuberous Sclerosis                |    HIV edge pred:     0.7075
# DZ: subependymal giant cell astrocytoma (SEGA)    |    HIV edge pred:     0.7075
# DZ: renal angiomyolipoma              |    HIV edge pred:     0.7075
# DZ: obsessive compulsive disorder (OCD)    |    HIV edge pred:     0.7075
# DZ: myelofibrosis                     |    HIV edge pred:     0.7075
# DZ: Abortion, Habitual                |    HIV edge pred:     0.7075
# DZ: Hypoplastic Anemia                |    HIV edge pred:     0.7075
# DZ: Dyspnea, Paroxysmal               |    HIV edge pred:     0.7074
# DZ: Mucopolysaccharidosis Vi          |    HIV edge pred:     0.7074
# DZ: mesothelioma                      |    HIV edge pred:     0.7074
# DZ: Hypogonadotropic Hypogonadism     |    HIV edge pred:     0.7073
# DZ: Growth Failure                    |    HIV edge pred:     0.7073
# DZ: Myeloproliferative Disease        |    HIV edge pred:     0.7073
# DZ: Stomach Carcinoma                 |    HIV edge pred:     0.7073
# DZ: cystic ovaries                    |    HIV edge pred:     0.7073
# DZ: Hyperinsulinism                   |    HIV edge pred:     0.7072
# DZ: Blood Coagulation Disorders       |    HIV edge pred:     0.7072
# DZ: Primary Biliary Cirrhosis         |    HIV edge pred:     0.7072
# DZ: hypophosphatemia                  |    HIV edge pred:     0.7072
# DZ: beta Thalassemia                  |    HIV edge pred:     0.7071
# DZ: Urolithiasis                      |    HIV edge pred:     0.7071
# DZ: Transient Cerebral Ischemia       |    HIV edge pred:      0.707
# DZ: Papillary thyroid carcinoma       |    HIV edge pred:     0.7069
# DZ: Myelodysplastic Syndrome          |    HIV edge pred:     0.7069
# DZ: Glioma                            |    HIV edge pred:     0.7068
# DZ: Testicular Hypogonadism           |    HIV edge pred:     0.7068
# DZ: hyperphenylalaninemia (HPA)       |    HIV edge pred:     0.7068
# DZ: Precursor T-Cell Lymphoblastic Leukemia-Lymphoma    |    HIV edge pred:     0.7067
# DZ: Renal Insufficiency               |    HIV edge pred:     0.7067
# DZ: spinocerebellar ataxia            |    HIV edge pred:     0.7067
# DZ: cachexia                          |    HIV edge pred:     0.7066
# DZ: Respiratory Hypersensitivity      |    HIV edge pred:     0.7066
# DZ: osteomalacia                      |    HIV edge pred:     0.7065
# DZ: Carcinoma, Transitional Cell      |    HIV edge pred:     0.7065
# DZ: Classical phenylketonuria         |    HIV edge pred:     0.7065
# DZ: Respiratory Insufficiency         |    HIV edge pred:     0.7065
# DZ: Thrombocytosis                    |    HIV edge pred:     0.7064
# DZ: Respiratory Distress Syndrome, Newborn    |    HIV edge pred:     0.7064
# DZ: Noonan Syndrome                   |    HIV edge pred:     0.7063
# DZ: Facial Paralysis                  |    HIV edge pred:     0.7063
# DZ: Cardiomyopathy, Dilated           |    HIV edge pred:     0.7063
# DZ: Chronic Neutrophilic Leukemia     |    HIV edge pred:     0.7062
# DZ: Prader-Willi Syndrome             |    HIV edge pred:      0.706
# DZ: Narcolepsy-Cataplexy Syndrome     |    HIV edge pred:      0.706
# DZ: Growth retardation                |    HIV edge pred:      0.706
# DZ: Arsenic Poisoning                 |    HIV edge pred:     0.7059
# DZ: Thrombophilia                     |    HIV edge pred:     0.7059
# DZ: Dysuria                           |    HIV edge pred:     0.7057
# DZ: abdominal pain                    |    HIV edge pred:     0.7057
# DZ: Pleural Effusion Disorder         |    HIV edge pred:     0.7056
# DZ: Myopathy                          |    HIV edge pred:     0.7056
# DZ: Infectious Disease Of Lung        |    HIV edge pred:     0.7056
# DZ: Systemic onset juvenile chronic arthritis    |    HIV edge pred:     0.7055
# DZ: Chronic Kidney Disease Stage 5    |    HIV edge pred:     0.7053
# DZ: Growth Disorders                  |    HIV edge pred:     0.7052
# DZ: Biliary Cirrhosis                 |    HIV edge pred:     0.7051
# DZ: Antithrombin Iii Deficiency       |    HIV edge pred:     0.7051
# DZ: Keratoconjunctivitis              |    HIV edge pred:      0.705
# DZ: Hyperparathyroidism, Secondary    |    HIV edge pred:     0.7048
# DZ: Deficiency of testosterone biosynthesis    |    HIV edge pred:     0.7048
# DZ: prostatitis                       |    HIV edge pred:     0.7046
# DZ: Chronic Diarrhea                  |    HIV edge pred:     0.7046
# DZ: onychomycosis                     |    HIV edge pred:     0.7045
# DZ: obstructive sleep apnea           |    HIV edge pred:     0.7045
# DZ: Hyperphosphatemia                 |    HIV edge pred:     0.7045
# DZ: Bronchiolitis                     |    HIV edge pred:     0.7044
# DZ: Hyperammonemia, Type Iii          |    HIV edge pred:     0.7043
# DZ: chronic kidney disease (CKD)      |    HIV edge pred:     0.7043
# DZ: Idiopathic Hypogonadotropic Hypogonadism    |    HIV edge pred:     0.7042
# DZ: Refractory Anemias                |    HIV edge pred:     0.7039
# DZ: respiratory depression            |    HIV edge pred:     0.7039
# DZ: Follicular thyroid carcinoma      |    HIV edge pred:     0.7039
# DZ: Osteoarthritis, Knee              |    HIV edge pred:     0.7037
# DZ: Chronic schizophrenia             |    HIV edge pred:     0.7037
# DZ: Ketosis                           |    HIV edge pred:     0.7036
# DZ: Autoimmune Thyroiditis            |    HIV edge pred:     0.7035
# DZ: blepharitis                       |    HIV edge pred:     0.7033
# DZ: Familial generalized lipodystrophy    |    HIV edge pred:     0.7031
# DZ: Dyskinesia, Drug-Induced          |    HIV edge pred:     0.7028
# DZ: Pimples                           |    HIV edge pred:     0.7026
# DZ: Paronychia Inflammation           |    HIV edge pred:     0.7022
# DZ: hip dysplasia                     |    HIV edge pred:     0.7022
# DZ: oligomenorrhea                    |    HIV edge pred:     0.7015
# DZ: Fetal Membranes, Premature Rupture    |    HIV edge pred:     0.7015
# DZ: chronic eosinophilic leukemia (CEL)    |    HIV edge pred:     0.7013
# DZ: episcleritis                      |    HIV edge pred:      0.701
# DZ: Peptic Esophagitis                |    HIV edge pred:     0.7006
# DZ: Porphyria Cutanea Tarda           |    HIV edge pred:     0.7002
# DZ: peripheral artery disease (PAD)    |    HIV edge pred:        0.7
# DZ: lumbago                           |    HIV edge pred:     0.6998
# DZ: paralytic ileus                   |    HIV edge pred:     0.6996
# DZ: Paroxysmal Nocturnal Hemoglobinuria    |    HIV edge pred:     0.6978
# DZ: gastritis                         |    HIV edge pred:     0.6974
# DZ: Precocious Puberty, Central       |    HIV edge pred:     0.6954
# DZ: Anaplastic Astrocytoma            |    HIV edge pred:      0.694
# DZ: Mucopolysaccharidosis Ii          |    HIV edge pred:     0.6936
# DZ: Acquired partial lipodystrophy    |    HIV edge pred:     0.6935
# DZ: HIV                               |    HIV edge pred:      0.684

# %%
# Write results to file
res_df.to_csv("../results/res3_val_0.467_.867_test_0.436_.874_total.tsv", sep="\t", index=False)
