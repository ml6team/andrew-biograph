# %%
import numpy as np
import pandas as pd
import torch
from load_msi import create_msi
from visualization import (
        generate_nx_graph, generate_khop_subgraph, generate_pyvis_graph, 
        visualize_tsne_embeddings, visualize_pca_embeddings)
from training import split_data, create_minibatches, train_link_predictor
from torch_geometric.utils import to_networkx, degree
from torch_geometric.nn import to_hetero

from gnn import GAT, GIN, DotProductLinkPredictor
import torch_geometric.transforms as T
print(torch.__version__)
# Out:
# 1.13.1+cu117

# %%
msi = create_msi("msi", 
                 num_features = 1,
                 data_dir="../multiscale_interactome/data")

data = msi.hetero_data
data = T.ToUndirected()(data)

# %%
# Generate and visualize graphs (HIV: id = C0019693, gid = 840)
##G, G_undirected = generate_nx_graph(msi.data)
##subG = generate_khop_subgraph(msi, G, 840, 1)
##py_graph = generate_pyvis_graph(subG)
##py_graph.show("test.html")

# %%
# Set the device.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
edge_type = ("dz", "implicates", "prot")
id_map = msi.mappings["dz_id_gid_map"]
name_map = msi.mappings["dz_id_name_map"]



degrees = degree(data[edge_type].edge_index[0]).numpy()
sorted_gids = np.argsort(degrees)[::-1]
sorted_degs = np.sort(degrees)[::-1]


#for gid, deg in zip(sorted_gids, sorted_degs):
#    id = list(id_map.keys())[list(id_map.values()).index(gid)]
#    name = name_map[id]
#    print(f"Disease: {name:<45}   |   1-hop neighbors: {deg:>5}   |   id: {id}")

# %%
# Prepare data for GNN.
edge_types = ("drug", "treats", "dz")
rev_edge_types = ("dz", "rev_treats", "drug")

# Split the data into train, validation, and test sets.
train_data, val_data, test_data = split_data(
        data, val_size=0.1, test_size=0.1, supervision_ratio=0.3,
        edge_types=edge_types, neg_sampling_ratio=1.0,
        rev_edge_types=rev_edge_types)


# Create minibatches.
train_loader = create_minibatches(
        train_data, edge_types=edge_types, num_khop_neighbors=[50,25,10], neg_sampling_ratio=1.0, batch_size=16)
val_loader = create_minibatches(
        val_data, edge_types=edge_types, num_khop_neighbors = [50,25,10], batch_size=16)

# %%
# Instantiate the model and generate some initial node embeddings prior to training.
model = GAT(4, 64, 16)
model = to_hetero(model, data.metadata(), aggr='sum').to(device)
predictor = DotProductLinkPredictor(32, 32, 1).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
#model.reset_parameters()
#predictor.reset_parameters()

# Train and validate the model for a given number of epochs.
for epoch in range(1, 50+1):
    
    # Training..
    loss, auc = train_link_predictor(
            model, predictor, "drug", "dz", edge_types=edge_types, 
            loader=train_loader, optimizer=optimizer, device=device, train=True)
    
    # Validation.
    val_loss, val_auc = train_link_predictor(
            model, predictor, "drug", "dz", edge_types=edge_types, 
            loader=val_loader,  optimizer=optimizer, device=device, train=False)
    
    print(f"Epoch     : {epoch}")
    print(f" Loss     : {loss:<10.4f} |     AUC:     {auc:>10.4f}")
    print(f" Val_Loss : {val_loss:<10.4f} |     Val_AUC: {val_auc:>10.4f}")
# Out:
# 100%|██████████| 89/89 [00:32<00:00,  2.71it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.36it/s]
# Epoch     : 1
#  Loss     : 38.7276    |     AUC:         0.5138
#  Val_Loss : 0.9099     |     Val_AUC:     0.4989
# 100%|██████████| 89/89 [00:30<00:00,  2.96it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.32it/s]
# Epoch     : 2
#  Loss     : 0.8807     |     AUC:         0.5207
#  Val_Loss : 0.8202     |     Val_AUC:     0.5069
# 100%|██████████| 89/89 [00:30<00:00,  2.93it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 3
#  Loss     : 0.8447     |     AUC:         0.4860
#  Val_Loss : 0.8477     |     Val_AUC:     0.5154
# 100%|██████████| 89/89 [00:30<00:00,  2.92it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.21it/s]
# Epoch     : 4
#  Loss     : 0.8095     |     AUC:         0.5015
#  Val_Loss : 0.7692     |     Val_AUC:     0.5039
# 100%|██████████| 89/89 [00:30<00:00,  2.91it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 5
#  Loss     : 2.1530     |     AUC:         0.5140
#  Val_Loss : 0.7850     |     Val_AUC:     0.4927
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 6
#  Loss     : 0.7613     |     AUC:         0.4922
#  Val_Loss : 0.7423     |     Val_AUC:     0.4999
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.17it/s]
# Epoch     : 7
#  Loss     : 0.7507     |     AUC:         0.5010
#  Val_Loss : 0.7325     |     Val_AUC:     0.4946
# 100%|██████████| 89/89 [00:30<00:00,  2.91it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.13it/s]
# Epoch     : 8
#  Loss     : 0.7736     |     AUC:         0.4981
#  Val_Loss : 0.7251     |     Val_AUC:     0.5045
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 9
#  Loss     : 0.7247     |     AUC:         0.5012
#  Val_Loss : 0.7385     |     Val_AUC:     0.5065
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.21it/s]
# Epoch     : 10
#  Loss     : 0.7074     |     AUC:         0.5072
#  Val_Loss : 0.7411     |     Val_AUC:     0.5078
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.18it/s]
# Epoch     : 11
#  Loss     : 0.6227     |     AUC:         0.6863
#  Val_Loss : 0.4864     |     Val_AUC:     0.7862
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.18it/s]
# Epoch     : 12
#  Loss     : 0.4925     |     AUC:         0.8085
#  Val_Loss : 0.3402     |     Val_AUC:     0.9043
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.16it/s]
# Epoch     : 13
#  Loss     : 0.4445     |     AUC:         0.8342
#  Val_Loss : 0.4182     |     Val_AUC:     0.8811
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.16it/s]
# Epoch     : 14
#  Loss     : 0.4429     |     AUC:         0.8542
#  Val_Loss : 0.3255     |     Val_AUC:     0.9131
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.17it/s]
# Epoch     : 15
#  Loss     : 0.3917     |     AUC:         0.8677
#  Val_Loss : 0.2595     |     Val_AUC:     0.9404
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.22it/s]
# Epoch     : 16
#  Loss     : 0.3690     |     AUC:         0.8850
#  Val_Loss : 0.5363     |     Val_AUC:     0.9364
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.19it/s]
# Epoch     : 17
#  Loss     : 0.3752     |     AUC:         0.8838
#  Val_Loss : 0.3027     |     Val_AUC:     0.9292
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.29it/s]
# Epoch     : 18
#  Loss     : 0.3845     |     AUC:         0.8749
#  Val_Loss : 0.2566     |     Val_AUC:     0.9367
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.14it/s]
# Epoch     : 19
#  Loss     : 0.3587     |     AUC:         0.8856
#  Val_Loss : 0.2656     |     Val_AUC:     0.9379
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.21it/s]
# Epoch     : 20
#  Loss     : 0.3657     |     AUC:         0.8877
#  Val_Loss : 0.2905     |     Val_AUC:     0.9299
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.16it/s]
# Epoch     : 21
#  Loss     : 0.3502     |     AUC:         0.8926
#  Val_Loss : 0.2984     |     Val_AUC:     0.9320
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.19it/s]
# Epoch     : 22
#  Loss     : 0.3589     |     AUC:         0.8854
#  Val_Loss : 0.3125     |     Val_AUC:     0.9257
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.26it/s]
# Epoch     : 23
#  Loss     : 0.3757     |     AUC:         0.8814
#  Val_Loss : 0.3204     |     Val_AUC:     0.9468
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.14it/s]
# Epoch     : 24
#  Loss     : 0.3479     |     AUC:         0.8892
#  Val_Loss : 0.2562     |     Val_AUC:     0.9322
# 100%|██████████| 89/89 [00:31<00:00,  2.87it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.22it/s]
# Epoch     : 25
#  Loss     : 0.3478     |     AUC:         0.8905
#  Val_Loss : 0.2718     |     Val_AUC:     0.9447
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.15it/s]
# Epoch     : 26
#  Loss     : 0.3494     |     AUC:         0.8871
#  Val_Loss : 0.2642     |     Val_AUC:     0.9417
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.17it/s]
# Epoch     : 27
#  Loss     : 0.3390     |     AUC:         0.8919
#  Val_Loss : 0.2358     |     Val_AUC:     0.9512
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 28
#  Loss     : 0.3445     |     AUC:         0.8988
#  Val_Loss : 0.3275     |     Val_AUC:     0.9344
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.21it/s]
# Epoch     : 29
#  Loss     : 0.3465     |     AUC:         0.8913
#  Val_Loss : 0.5057     |     Val_AUC:     0.9430
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 30
#  Loss     : 0.3360     |     AUC:         0.9062
#  Val_Loss : 0.2785     |     Val_AUC:     0.9556
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.16it/s]
# Epoch     : 31
#  Loss     : 0.3362     |     AUC:         0.9013
#  Val_Loss : 0.3014     |     Val_AUC:     0.9421
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 32
#  Loss     : 0.3474     |     AUC:         0.8888
#  Val_Loss : 0.2548     |     Val_AUC:     0.9481
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.25it/s]
# Epoch     : 33
#  Loss     : 0.3386     |     AUC:         0.9071
#  Val_Loss : 0.3418     |     Val_AUC:     0.9476
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.10it/s]
# Epoch     : 34
#  Loss     : 0.3265     |     AUC:         0.9036
#  Val_Loss : 0.3175     |     Val_AUC:     0.9471
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.09it/s]
# Epoch     : 35
#  Loss     : 0.3435     |     AUC:         0.8924
#  Val_Loss : 0.2310     |     Val_AUC:     0.9606
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.18it/s]
# Epoch     : 36
#  Loss     : 0.3415     |     AUC:         0.8983
#  Val_Loss : 0.2647     |     Val_AUC:     0.9390
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.18it/s]
# Epoch     : 37
#  Loss     : 0.3184     |     AUC:         0.9030
#  Val_Loss : 0.2478     |     Val_AUC:     0.9436
# 100%|██████████| 89/89 [00:30<00:00,  2.91it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.24it/s]
# Epoch     : 38
#  Loss     : 0.3433     |     AUC:         0.8936
#  Val_Loss : 0.2563     |     Val_AUC:     0.9412
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 39
#  Loss     : 0.3372     |     AUC:         0.8940
#  Val_Loss : 0.2536     |     Val_AUC:     0.9355
# 100%|██████████| 89/89 [00:30<00:00,  2.87it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.21it/s]
# Epoch     : 40
#  Loss     : 0.3393     |     AUC:         0.8982
#  Val_Loss : 0.2751     |     Val_AUC:     0.9206
# 100%|██████████| 89/89 [00:31<00:00,  2.87it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.15it/s]
# Epoch     : 41
#  Loss     : 0.3300     |     AUC:         0.9016
#  Val_Loss : 0.2625     |     Val_AUC:     0.9479
# 100%|██████████| 89/89 [00:30<00:00,  2.91it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.24it/s]
# Epoch     : 42
#  Loss     : 0.3363     |     AUC:         0.8967
#  Val_Loss : 0.6504     |     Val_AUC:     0.8410
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.20it/s]
# Epoch     : 43
#  Loss     : 0.3430     |     AUC:         0.9022
#  Val_Loss : 0.3031     |     Val_AUC:     0.9406
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.22it/s]
# Epoch     : 44
#  Loss     : 0.3383     |     AUC:         0.8926
#  Val_Loss : 0.2531     |     Val_AUC:     0.9432
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.19it/s]
# Epoch     : 45
#  Loss     : 0.3577     |     AUC:         0.8942
#  Val_Loss : 0.2532     |     Val_AUC:     0.9458
# 100%|██████████| 89/89 [00:30<00:00,  2.89it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.19it/s]
# Epoch     : 46
#  Loss     : 0.3392     |     AUC:         0.9083
#  Val_Loss : 0.2495     |     Val_AUC:     0.9382
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.16it/s]
# Epoch     : 47
#  Loss     : 0.3361     |     AUC:         0.8994
#  Val_Loss : 0.2423     |     Val_AUC:     0.9512
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.24it/s]
# Epoch     : 48
#  Loss     : 0.3192     |     AUC:         0.9156
#  Val_Loss : 0.2240     |     Val_AUC:     0.9647
# 100%|██████████| 89/89 [00:30<00:00,  2.88it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.17it/s]
# Epoch     : 49
#  Loss     : 0.3385     |     AUC:         0.9021
#  Val_Loss : 0.2565     |     Val_AUC:     0.9599
# 100%|██████████| 89/89 [00:30<00:00,  2.90it/s]
# 100%|██████████| 74/74 [00:10<00:00,  7.13it/s]
# Epoch     : 50
#  Loss     : 0.3046     |     AUC:         0.9172
#  Val_Loss : 0.2780     |     Val_AUC:     0.9456

# %%
msi = create_msi("msi-hiv", 
                 num_features = 1,
                 data_dir="../multiscale_interactome/data", 
                 extra_dz_data="../data/hiv/hiv_protein30.tsv")

hiv_data = msi.hetero_data
hiv_data = T.ToUndirected()(hiv_data)
#(HIV: id = C0019693, gid = 840)
hiv_id = "C0019693"
hiv_gid = 840

# %%
def get_node_embeddings(model, data):
    model.eval()
    z = model(data.x_dict, data.edge_index_dict)
    return z

# %%
hiv_data.to("cpu")
model.to("cpu")
predictor.to("cpu")
# Out:
# DotProductLinkPredictor(
#   (lin1): Linear(32, 32, bias=True)
#   (lin2): Linear(32, 1, bias=True)
# )

# %%
torch.cuda.empty_cache()
#print("torch.cuda.memory_allocated: %fGB"%(torch.cuda.memory_allocated(0)/1024/1024/1024))
#print("torch.cuda.memory_reserved: %fGB"%(torch.cuda.memory_reserved(0)/1024/1024/1024))
#print("torch.cuda.max_memory_reserved: %fGB"%(torch.cuda.max_memory_reserved(0)/1024/1024/1024))
#print(torch.cuda.memory_summary(device=None, abbreviated=False))

# %%
z = get_node_embeddings(model, hiv_data)
z = model(hiv_data.x_dict, hiv_data.edge_index_dict)
z_drugs = z["drug"]
z_dz = z["dz"]
hiv_emb = z["dz"][hiv_gid]

# %%
from numpy import dot
from numpy.linalg import norm



#hiv_emb = hiv_emb.cpu().detach().numpy()
drug_edge_preds = []
dz_edge_preds = []
for drug_emb in z_drugs:
    drug_edge_pred = predictor(drug_emb, hiv_emb)
    drug_edge_pred = drug_edge_pred.detach().numpy()
    drug_edge_preds.append(drug_edge_pred)
drug_sorted_edges = np.sort(drug_edge_preds)[::-1]
drug_sorted_ind = np.argsort(drug_edge_preds)[::-1]


for dz_emb in z_dz:
    dz_edge_pred = predictor(dz_emb, hiv_emb)
    dz_edge_pred = dz_edge_pred.detach().numpy()
    dz_edge_preds.append(dz_edge_pred)
dz_sorted_edges = np.sort(dz_edge_preds)[::-1]
dz_sorted_ind = np.argsort(dz_edge_preds)[::-1]

# %%
import pandas as pd
id_list = []
drug_list = []
sim_list = []
for ind, edge in zip(drug_sorted_ind, drug_sorted_edges):
    id = [i for i in msi.mappings["drug_id_gid_map"] if msi.mappings["drug_id_gid_map"][i] == ind][0]
    drug = msi.mappings["drug_id_name_map"][id]
    id_list.append(id)
    drug_list.append(drug)
    sim_list.append(edge)
    print(f"Drug: {drug:<30}    |    HIV edge pred: {edge:>10.4}")

res_dict = {"id":id_list, "name" : drug_list, "similarity" : sim_list}
res_df = pd.DataFrame(res_dict)

print("\n\n\n")

for ind, edge in zip(dz_sorted_ind, dz_sorted_edges):
    id = [i for i in msi.mappings["dz_id_gid_map"] if msi.mappings["dz_id_gid_map"][i] == ind][0]
    dz = msi.mappings["dz_id_name_map"][id]
    print(f"DZ: {dz:<30}    |    HIV edge pred: {edge:>10.4}")

res_dict = {"id":id_list, "name" : drug_list, "similarity" : sim_list}
res_df = pd.DataFrame(res_dict)
# Out:
# Drug: nan                               |    HIV edge pred:      2.233
# Drug: Dexfenfluramine                   |    HIV edge pred:      2.072
# Drug: nan                               |    HIV edge pred:      2.054
# Drug: enoximone                         |    HIV edge pred:      1.985
# Drug: nan                               |    HIV edge pred:      1.898
# Drug: mianserin                         |    HIV edge pred:      1.873
# Drug: viloxazine                        |    HIV edge pred:      1.856
# Drug: risperidone                       |    HIV edge pred:      1.832
# Drug: hyaluronidase (ovine)             |    HIV edge pred:      1.821
# Drug: ethynodiol-diacetate              |    HIV edge pred:      1.815
# Drug: Azelaic Acid                      |    HIV edge pred:      1.814
# Drug: tolbutamide                       |    HIV edge pred:      1.812
# Drug: carprofen                         |    HIV edge pred:      1.797
# Drug: mitiglinide                       |    HIV edge pred:      1.762
# Drug: estradiol                         |    HIV edge pred:      1.759
# Drug: diclofenamide                     |    HIV edge pred:      1.757
# Drug: Benzocaine                        |    HIV edge pred:      1.755
# Drug: Eculizumab                        |    HIV edge pred:       1.75
# Drug: oxyphencyclimine                  |    HIV edge pred:      1.743
# Drug: rifapentine                       |    HIV edge pred:      1.704
# Drug: rivastigmine                      |    HIV edge pred:      1.676
# Drug: Lithium                           |    HIV edge pred:      1.671
# Drug: quinestrol                        |    HIV edge pred:      1.619
# Drug: olmesartan                        |    HIV edge pred:      1.612
# Drug: Ustekinumab                       |    HIV edge pred:      1.603
# Drug: nan                               |    HIV edge pred:      1.594
# Drug: dopamine                          |    HIV edge pred:      1.592
# Drug: dicoumarol                        |    HIV edge pred:      1.589
# Drug: nan                               |    HIV edge pred:      1.577
# Drug: fulvestrant                       |    HIV edge pred:      1.557
# Drug: Udenafil                          |    HIV edge pred:      1.551
# Drug: imipramine                        |    HIV edge pred:      1.551
# Drug: halcinonide                       |    HIV edge pred:      1.542
# Drug: exemestane                        |    HIV edge pred:      1.524
# Drug: exenatide                         |    HIV edge pred:      1.523
# Drug: ECALLANTIDE                       |    HIV edge pred:      1.521
# Drug: nan                               |    HIV edge pred:      1.521
# Drug: captopril                         |    HIV edge pred:      1.502
# Drug: norelgestromin                    |    HIV edge pred:      1.498
# Drug: chlorzoxazone                     |    HIV edge pred:       1.49
# Drug: protriptyline                     |    HIV edge pred:      1.487
# Drug: nan                               |    HIV edge pred:      1.473
# Drug: ciclopirox                        |    HIV edge pred:      1.472
# Drug: Nivolumab                         |    HIV edge pred:      1.472
# Drug: pravastatin                       |    HIV edge pred:      1.467
# Drug: Phenmetrazine                     |    HIV edge pred:      1.467
# Drug: flurbiprofen-(+/-)                |    HIV edge pred:      1.467
# Drug: moracizine                        |    HIV edge pred:      1.461
# Drug: ciprofloxacin                     |    HIV edge pred:      1.458
# Drug: reserpine                         |    HIV edge pred:      1.457
# Drug: letrozole                         |    HIV edge pred:      1.453
# Drug: warfarin                          |    HIV edge pred:      1.448
# Drug: Fentanyl                          |    HIV edge pred:      1.448
# Drug: hydrocortisone                    |    HIV edge pred:      1.437
# Drug: sodium ferric gluconate complex    |    HIV edge pred:      1.432
# Drug: Sibutramine                       |    HIV edge pred:      1.429
# Drug: THROMBOMODULIN ALFA               |    HIV edge pred:      1.421
# Drug: aprepitant                        |    HIV edge pred:       1.42
# Drug: MAGNESIUM ACETATE                 |    HIV edge pred:      1.418
# Drug: nan                               |    HIV edge pred:      1.415
# Drug: tolperisone                       |    HIV edge pred:      1.411
# Drug: nan                               |    HIV edge pred:      1.409
# Drug: ethinamate                        |    HIV edge pred:      1.408
# Drug: Corticotropin                     |    HIV edge pred:      1.406
# Drug: simeprevir                        |    HIV edge pred:      1.402
# Drug: TUROCTOCOG ALFA                   |    HIV edge pred:      1.401
# Drug: Trifluridine                      |    HIV edge pred:      1.397
# Drug: maxacalcitol                      |    HIV edge pred:       1.39
# Drug: Salmon Calcitonin                 |    HIV edge pred:       1.39
# Drug: Reteplase                         |    HIV edge pred:      1.383
# Drug: Somatropin recombinant            |    HIV edge pred:      1.382
# Drug: metaproterenol                    |    HIV edge pred:      1.378
# Drug: chloroxine                        |    HIV edge pred:      1.378
# Drug: bupivacaine                       |    HIV edge pred:      1.376
# Drug: trifluoperazine                   |    HIV edge pred:      1.374
# Drug: liraglutide                       |    HIV edge pred:      1.372
# Drug: sipuleucel-T                      |    HIV edge pred:      1.368
# Drug: methylnaltrexone                  |    HIV edge pred:      1.367
# Drug: nan                               |    HIV edge pred:      1.365
# Drug: medrysone                         |    HIV edge pred:      1.365
# Drug: nan                               |    HIV edge pred:      1.364
# Drug: Camphor                           |    HIV edge pred:      1.363
# Drug: Phenylbutazone                    |    HIV edge pred:      1.362
# Drug: amcinonide                        |    HIV edge pred:       1.36
# Drug: tenoxicam                         |    HIV edge pred:      1.357
# Drug: hexoprenaline                     |    HIV edge pred:      1.355
# Drug: nilutamide                        |    HIV edge pred:      1.351
# Drug: pralidoxime                       |    HIV edge pred:      1.348
# Drug: brentuximab vedotin               |    HIV edge pred:      1.346
# Drug: ataluren                          |    HIV edge pred:      1.344
# Drug: pizotifen                         |    HIV edge pred:      1.339
# Drug: ibuprofen                         |    HIV edge pred:      1.337
# Drug: bupranolol                        |    HIV edge pred:      1.337
# Drug: guanadrel                         |    HIV edge pred:      1.335
# Drug: Infliximab                        |    HIV edge pred:      1.333
# Drug: fluvastatin                       |    HIV edge pred:       1.33
# Drug: nan                               |    HIV edge pred:      1.328
# Drug: cisplatin                         |    HIV edge pred:      1.327
# Drug: phenprocoumon                     |    HIV edge pred:      1.327
# Drug: nisoldipine                       |    HIV edge pred:      1.326
# Drug: Thioridazine                      |    HIV edge pred:      1.325
# Drug: oxymetazoline                     |    HIV edge pred:      1.324
# Drug: imidafenacin                      |    HIV edge pred:      1.315
# Drug: Aluminium chloride                |    HIV edge pred:      1.313
# Drug: nan                               |    HIV edge pred:      1.311
# Drug: cilostazol                        |    HIV edge pred:      1.303
# Drug: venetoclax                        |    HIV edge pred:        1.3
# Drug: gliquidone                        |    HIV edge pred:      1.299
# Drug: nan                               |    HIV edge pred:      1.297
# Drug: nan                               |    HIV edge pred:      1.296
# Drug: Remikiren                         |    HIV edge pred:      1.293
# Drug: sarpogrelate                      |    HIV edge pred:      1.292
# Drug: moxifloxacin                      |    HIV edge pred:      1.289
# Drug: Metipranolol                      |    HIV edge pred:      1.287
# Drug: nan                               |    HIV edge pred:      1.286
# Drug: acetylcholine                     |    HIV edge pred:      1.284
# Drug: aripiprazole                      |    HIV edge pred:      1.283
# Drug: nelarabine                        |    HIV edge pred:       1.28
# Drug: methantheline                     |    HIV edge pred:      1.279
# Drug: mirabegron                        |    HIV edge pred:      1.276
# Drug: cyclopentolate                    |    HIV edge pred:      1.274
# Drug: lercanidipine                     |    HIV edge pred:      1.271
# Drug: diltiazem                         |    HIV edge pred:       1.27
# Drug: Salicylic acid                    |    HIV edge pred:      1.264
# Drug: Gamma Hydroxybutyric Acid         |    HIV edge pred:      1.263
# Drug: sucralfate                        |    HIV edge pred:      1.261
# Drug: benzbromarone                     |    HIV edge pred:       1.26
# Drug: phenylbutyrate                    |    HIV edge pred:      1.258
# Drug: Calcidiol                         |    HIV edge pred:      1.257
# Drug: azacitidine                       |    HIV edge pred:      1.256
# Drug: nan                               |    HIV edge pred:      1.255
# Drug: sivelestat                        |    HIV edge pred:      1.255
# Drug: sulfamethoxazole                  |    HIV edge pred:      1.254
# Drug: gestrinone                        |    HIV edge pred:      1.253
# Drug: nan                               |    HIV edge pred:       1.25
# Drug: dicycloverine                     |    HIV edge pred:      1.247
# Drug: lovastatin                        |    HIV edge pred:      1.241
# Drug: scopolamine                       |    HIV edge pred:      1.237
# Drug: pirenzepine                       |    HIV edge pred:      1.234
# Drug: metformin                         |    HIV edge pred:      1.232
# Drug: Lixisenatide                      |    HIV edge pred:      1.229
# Drug: dapsone                           |    HIV edge pred:      1.229
# Drug: carglumic-acid                    |    HIV edge pred:      1.229
# Drug: tulobuterol                       |    HIV edge pred:      1.228
# Drug: cefazolin                         |    HIV edge pred:      1.227
# Drug: nan                               |    HIV edge pred:      1.221
# Drug: chlorphenamine                    |    HIV edge pred:      1.214
# Drug: nan                               |    HIV edge pred:      1.213
# Drug: golimumab                         |    HIV edge pred:      1.211
# Drug: sumatriptan                       |    HIV edge pred:      1.206
# Drug: Pegaptanib                        |    HIV edge pred:      1.205
# Drug: amitriptyline                     |    HIV edge pred:      1.204
# Drug: nan                               |    HIV edge pred:      1.203
# Drug: rotigotine                        |    HIV edge pred:      1.203
# Drug: Amphetamine                       |    HIV edge pred:      1.202
# Drug: isoxsuprine                       |    HIV edge pred:      1.201
# Drug: tapentadol                        |    HIV edge pred:        1.2
# Drug: mitoxantrone                      |    HIV edge pred:      1.196
# Drug: erythromycin                      |    HIV edge pred:      1.196
# Drug: norgestrel                        |    HIV edge pred:      1.194
# Drug: Sucroferric Oxyhydroxide          |    HIV edge pred:       1.19
# Drug: nan                               |    HIV edge pred:      1.188
# Drug: axitinib                          |    HIV edge pred:      1.186
# Drug: floxuridine                       |    HIV edge pred:      1.186
# Drug: SIMOCTOCOG ALFA                   |    HIV edge pred:      1.186
# Drug: tibolone                          |    HIV edge pred:      1.186
# Drug: mexiletine                        |    HIV edge pred:      1.185
# Drug: tranylcypromine                   |    HIV edge pred:      1.184
# Drug: seratrodast                       |    HIV edge pred:      1.178
# Drug: tacalcitol                        |    HIV edge pred:      1.176
# Drug: vildagliptin                      |    HIV edge pred:      1.174
# Drug: GINSENG                           |    HIV edge pred:      1.173
# Drug: Lepirudin                         |    HIV edge pred:      1.171
# Drug: nan                               |    HIV edge pred:      1.168
# Drug: trilostane                        |    HIV edge pred:      1.166
# Drug: Collagenase clostridium histolyticum    |    HIV edge pred:      1.162
# Drug: quetiapine                        |    HIV edge pred:      1.159
# Drug: Methylscopolamine bromide         |    HIV edge pred:      1.157
# Drug: liothyronine                      |    HIV edge pred:      1.157
# Drug: finafloxacin                      |    HIV edge pred:      1.156
# Drug: Arbutamine                        |    HIV edge pred:      1.156
# Drug: fluoxetine                        |    HIV edge pred:      1.155
# Drug: betaine                           |    HIV edge pred:      1.154
# Drug: tolterodine                       |    HIV edge pred:      1.153
# Drug: telbivudine                       |    HIV edge pred:      1.152
# Drug: pitavastatin                      |    HIV edge pred:      1.152
# Drug: drospirenone                      |    HIV edge pred:      1.151
# Drug: ofloxacin                         |    HIV edge pred:      1.151
# Drug: debrisoquin                       |    HIV edge pred:      1.151
# Drug: nan                               |    HIV edge pred:       1.15
# Drug: flumethasone                      |    HIV edge pred:       1.15
# Drug: firocoxib                         |    HIV edge pred:      1.148
# Drug: perindopril                       |    HIV edge pred:      1.146
# Drug: benfotiamine                      |    HIV edge pred:      1.145
# Drug: Pegvisomant                       |    HIV edge pred:      1.144
# Drug: citalopram                        |    HIV edge pred:      1.144
# Drug: Iron                              |    HIV edge pred:      1.138
# Drug: chlorprothixene                   |    HIV edge pred:      1.137
# Drug: rufinamide                        |    HIV edge pred:      1.137
# Drug: nan                               |    HIV edge pred:      1.137
# Drug: Captodiame                        |    HIV edge pred:      1.136
# Drug: icosapent                         |    HIV edge pred:      1.134
# Drug: Trimetrexate                      |    HIV edge pred:      1.132
# Drug: edaravone                         |    HIV edge pred:      1.131
# Drug: Omega-3-carboxylic acids          |    HIV edge pred:      1.131
# Drug: clobetasol-propionate             |    HIV edge pred:       1.13
# Drug: cariprazine                       |    HIV edge pred:      1.129
# Drug: tetracaine                        |    HIV edge pred:      1.127
# Drug: nan                               |    HIV edge pred:      1.127
# Drug: beclomethasone-dipropionate       |    HIV edge pred:      1.127
# Drug: vismodegib                        |    HIV edge pred:      1.126
# Drug: neostigmine                       |    HIV edge pred:      1.125
# Drug: nadolol                           |    HIV edge pred:      1.122
# Drug: oxymetholone                      |    HIV edge pred:      1.122
# Drug: umeclidinium                      |    HIV edge pred:      1.118
# Drug: acenocoumarol                     |    HIV edge pred:      1.117
# Drug: bisoprolol                        |    HIV edge pred:      1.116
# Drug: cabergoline                       |    HIV edge pred:      1.114
# Drug: Anistreplase                      |    HIV edge pred:      1.114
# Drug: Ibritumomab tiuxetan              |    HIV edge pred:      1.108
# Drug: iguratimod                        |    HIV edge pred:      1.103
# Drug: paliperidone                      |    HIV edge pred:      1.102
# Drug: adenosine                         |    HIV edge pred:      1.092
# Drug: CROFELEMER                        |    HIV edge pred:      1.088
# Drug: alclofenac                        |    HIV edge pred:      1.087
# Drug: nintedanib                        |    HIV edge pred:      1.086
# Drug: levallorphan                      |    HIV edge pred:      1.085
# Drug: nan                               |    HIV edge pred:      1.078
# Drug: halofuginone                      |    HIV edge pred:      1.077
# Drug: cefdinir                          |    HIV edge pred:      1.077
# Drug: eliglustat                        |    HIV edge pred:      1.076
# Drug: otilonium                         |    HIV edge pred:      1.075
# Drug: salmeterol                        |    HIV edge pred:      1.075
# Drug: tiludronate                       |    HIV edge pred:      1.074
# Drug: venlafaxine                       |    HIV edge pred:      1.074
# Drug: levobunolol                       |    HIV edge pred:      1.073
# Drug: methylprednisolone                |    HIV edge pred:      1.073
# Drug: mazindol                          |    HIV edge pred:      1.072
# Drug: Arsenic trioxide                  |    HIV edge pred:       1.07
# Drug: temozolomide                      |    HIV edge pred:      1.069
# Drug: nan                               |    HIV edge pred:      1.069
# Drug: citicoline                        |    HIV edge pred:      1.069
# Drug: griseofulvin                      |    HIV edge pred:      1.069
# Drug: capecitabine                      |    HIV edge pred:      1.067
# Drug: Adinazolam                        |    HIV edge pred:      1.064
# Drug: Rosiglitazone                     |    HIV edge pred:      1.064
# Drug: vorapaxar                         |    HIV edge pred:      1.062
# Drug: Rilonacept                        |    HIV edge pred:      1.062
# Drug: eluxadoline                       |    HIV edge pred:      1.058
# Drug: atorvastatin                      |    HIV edge pred:      1.056
# Drug: goserelin-acetate                 |    HIV edge pred:      1.054
# Drug: riluzole                          |    HIV edge pred:       1.05
# Drug: calcitriol                        |    HIV edge pred:      1.048
# Drug: Fluocinolone Acetonide            |    HIV edge pred:      1.047
# Drug: serotonin                         |    HIV edge pred:      1.045
# Drug: duloxetine                        |    HIV edge pred:      1.045
# Drug: loxapine                          |    HIV edge pred:      1.043
# Drug: cinnarizine                       |    HIV edge pred:      1.042
# Drug: Terfenadine                       |    HIV edge pred:      1.041
# Drug: levomepromazine                   |    HIV edge pred:      1.041
# Drug: cysteamine                        |    HIV edge pred:      1.039
# Drug: nan                               |    HIV edge pred:      1.038
# Drug: prochlorperazine                  |    HIV edge pred:      1.033
# Drug: nan                               |    HIV edge pred:      1.032
# Drug: acetylcysteine                    |    HIV edge pred:       1.03
# Drug: indomethacin                      |    HIV edge pred:       1.03
# Drug: ondansetron                       |    HIV edge pred:       1.03
# Drug: metoprolol                        |    HIV edge pred:      1.028
# Drug: etizolam                          |    HIV edge pred:      1.028
# Drug: test_drug                         |    HIV edge pred:      1.028
# Drug: nan                               |    HIV edge pred:      1.027
# Drug: ticagrelor                        |    HIV edge pred:      1.027
# Drug: alverine                          |    HIV edge pred:      1.026
# Drug: acetohexamide                     |    HIV edge pred:      1.025
# Drug: tacrolimus                        |    HIV edge pred:      1.021
# Drug: Pirbuterol                        |    HIV edge pred:      1.018
# Drug: guanethidine                      |    HIV edge pred:      1.017
# Drug: DIFLORASONE                       |    HIV edge pred:      1.015
# Drug: CANGRELOR                         |    HIV edge pred:      1.013
# Drug: phenyl-salicylate                 |    HIV edge pred:      1.012
# Drug: Estrone                           |    HIV edge pred:      1.008
# Drug: clenbuterol                       |    HIV edge pred:      1.008
# Drug: Dexmethylphenidate                |    HIV edge pred:      1.007
# Drug: pixantrone                        |    HIV edge pred:      1.005
# Drug: Insulin Glargine                  |    HIV edge pred:      1.004
# Drug: glimepiride                       |    HIV edge pred:      1.002
# Drug: doxifluridine                     |    HIV edge pred:     0.9986
# Drug: norgestimate                      |    HIV edge pred:     0.9976
# Drug: glyburide                         |    HIV edge pred:     0.9973
# Drug: nan                               |    HIV edge pred:     0.9965
# Drug: eptifibatide                      |    HIV edge pred:     0.9919
# Drug: nan                               |    HIV edge pred:     0.9916
# Drug: clinofibrate                      |    HIV edge pred:     0.9909
# Drug: CLOCORTOLONE                      |    HIV edge pred:     0.9904
# Drug: Morphine                          |    HIV edge pred:     0.9892
# Drug: methylphenidate                   |    HIV edge pred:     0.9891
# Drug: mesalazine                        |    HIV edge pred:     0.9869
# Drug: meclofenamic-acid                 |    HIV edge pred:     0.9865
# Drug: SULPIRIDE                         |    HIV edge pred:     0.9857
# Drug: Atezolizumab                      |    HIV edge pred:     0.9843
# Drug: propiverine                       |    HIV edge pred:     0.9841
# Drug: vilanterol                        |    HIV edge pred:     0.9838
# Drug: Bromfenac                         |    HIV edge pred:      0.983
# Drug: glipizide                         |    HIV edge pred:     0.9808
# Drug: fluvoxamine                       |    HIV edge pred:     0.9791
# Drug: nan                               |    HIV edge pred:     0.9791
# Drug: Ramucirumab                       |    HIV edge pred:     0.9787
# Drug: imatinib                          |    HIV edge pred:      0.977
# Drug: probucol                          |    HIV edge pred:     0.9765
# Drug: regadenoson                       |    HIV edge pred:     0.9764
# Drug: Rifabutin                         |    HIV edge pred:     0.9763
# Drug: naloxone                          |    HIV edge pred:     0.9748
# Drug: tadalafil                         |    HIV edge pred:     0.9737
# Drug: flecainide                        |    HIV edge pred:     0.9734
# Drug: allylestrenol                     |    HIV edge pred:     0.9725
# Drug: arotinolol                        |    HIV edge pred:     0.9722
# Drug: brompheniramine                   |    HIV edge pred:      0.972
# Drug: nan                               |    HIV edge pred:      0.971
# Drug: etoricoxib                        |    HIV edge pred:      0.971
# Drug: imiquimod                         |    HIV edge pred:     0.9708
# Drug: sonidegib                         |    HIV edge pred:     0.9669
# Drug: dacarbazine                       |    HIV edge pred:     0.9657
# Drug: verapamil                         |    HIV edge pred:     0.9649
# Drug: monobenzone                       |    HIV edge pred:     0.9641
# Drug: bazedoxifene                      |    HIV edge pred:      0.964
# Drug: ambenonium                        |    HIV edge pred:     0.9635
# Drug: lenalidomide                      |    HIV edge pred:     0.9632
# Drug: nan                               |    HIV edge pred:     0.9584
# Drug: nan                               |    HIV edge pred:     0.9577
# Drug: propiomazine                      |    HIV edge pred:      0.956
# Drug: nan                               |    HIV edge pred:     0.9545
# Drug: triflupromazine                   |    HIV edge pred:     0.9543
# Drug: Pembrolizumab                     |    HIV edge pred:     0.9541
# Drug: ethotoin                          |    HIV edge pred:      0.954
# Drug: nan                               |    HIV edge pred:     0.9478
# Drug: cyclizine                         |    HIV edge pred:     0.9466
# Drug: belinostat                        |    HIV edge pred:     0.9417
# Drug: raltitrexed                       |    HIV edge pred:     0.9412
# Drug: promethazine                      |    HIV edge pred:     0.9409
# Drug: cleviprex                         |    HIV edge pred:     0.9366
# Drug: levonorgestrel                    |    HIV edge pred:     0.9358
# Drug: cabozantinib                      |    HIV edge pred:     0.9354
# Drug: oxcarbazepine                     |    HIV edge pred:     0.9342
# Drug: gemfibrozil                       |    HIV edge pred:      0.933
# Drug: nan                               |    HIV edge pred:     0.9328
# Drug: fosaprepitant-dimeglumine         |    HIV edge pred:     0.9322
# Drug: rutin                             |    HIV edge pred:      0.931
# Drug: loperamide                        |    HIV edge pred:     0.9296
# Drug: fluorometholone                   |    HIV edge pred:     0.9295
# Drug: methimazole                       |    HIV edge pred:     0.9282
# Drug: benzthiazide                      |    HIV edge pred:      0.928
# Drug: Tasosartan                        |    HIV edge pred:     0.9278
# Drug: medroxyprogesterone acetate       |    HIV edge pred:     0.9275
# Drug: Tolcapone                         |    HIV edge pred:     0.9271
# Drug: aliskiren-hemifumarate            |    HIV edge pred:     0.9237
# Drug: trazodone                         |    HIV edge pred:     0.9226
# Drug: lurasidone                        |    HIV edge pred:     0.9223
# Drug: nan                               |    HIV edge pred:     0.9209
# Drug: lorcaserin                        |    HIV edge pred:     0.9208
# Drug: nan                               |    HIV edge pred:     0.9204
# Drug: epinephrine                       |    HIV edge pred:     0.9197
# Drug: Homatropine Methylbromide         |    HIV edge pred:      0.918
# Drug: Zopiclone                         |    HIV edge pred:     0.9176
# Drug: fenoldopam                        |    HIV edge pred:     0.9151
# Drug: nan                               |    HIV edge pred:     0.9134
# Drug: metolazone                        |    HIV edge pred:      0.913
# Drug: sulindac                          |    HIV edge pred:     0.9119
# Drug: nan                               |    HIV edge pred:     0.9118
# Drug: nan                               |    HIV edge pred:     0.9106
# Drug: dimethyl-fumarate                 |    HIV edge pred:     0.9097
# Drug: metharbital                       |    HIV edge pred:     0.9088
# Drug: piribedil                         |    HIV edge pred:     0.9084
# Drug: glutamine-(l)                     |    HIV edge pred:      0.906
# Drug: Sitaxentan                        |    HIV edge pred:      0.906
# Drug: nan                               |    HIV edge pred:     0.9054
# Drug: zileuton                          |    HIV edge pred:     0.9019
# Drug: Cinitapride                       |    HIV edge pred:     0.9014
# Drug: hydroxyurea                       |    HIV edge pred:     0.9013
# Drug: nan                               |    HIV edge pred:     0.9011
# Drug: lasofoxifene                      |    HIV edge pred:     0.9006
# Drug: nalbuphine                        |    HIV edge pred:     0.9003
# Drug: regorafenib                       |    HIV edge pred:     0.8997
# Drug: ritodrine                         |    HIV edge pred:     0.8996
# Drug: metoclopramide                    |    HIV edge pred:     0.8993
# Drug: prasugrel                         |    HIV edge pred:     0.8978
# Drug: chlorcyclizine                    |    HIV edge pred:     0.8928
# Drug: tiaprofenic-acid                  |    HIV edge pred:     0.8928
# Drug: Pentobarbital                     |    HIV edge pred:     0.8926
# Drug: Belimumab                         |    HIV edge pred:     0.8922
# Drug: propranolol                       |    HIV edge pred:     0.8903
# Drug: roxatidine-acetate                |    HIV edge pred:     0.8901
# Drug: nan                               |    HIV edge pred:     0.8899
# Drug: resorcinol                        |    HIV edge pred:     0.8837
# Drug: octanoic acid                     |    HIV edge pred:     0.8832
# Drug: Natalizumab                       |    HIV edge pred:     0.8807
# Drug: Oxycodone                         |    HIV edge pred:     0.8801
# Drug: nebivolol                         |    HIV edge pred:     0.8799
# Drug: norethindrone                     |    HIV edge pred:     0.8795
# Drug: safinamide                        |    HIV edge pred:     0.8779
# Drug: amantadine                        |    HIV edge pred:      0.877
# Drug: vemurafenib                       |    HIV edge pred:      0.873
# Drug: Cetuximab                         |    HIV edge pred:     0.8729
# Drug: zotepine                          |    HIV edge pred:     0.8729
# Drug: Anisotropine Methylbromide        |    HIV edge pred:     0.8717
# Drug: ramelteon                         |    HIV edge pred:     0.8714
# Drug: OPICAPONE                         |    HIV edge pred:     0.8713
# Drug: Hydromorphone                     |    HIV edge pred:     0.8703
# Drug: pralatrexate                      |    HIV edge pred:     0.8685
# Drug: levosimendan                      |    HIV edge pred:     0.8674
# Drug: chlorpromazine                    |    HIV edge pred:      0.867
# Drug: doxercalciferol                   |    HIV edge pred:     0.8664
# Drug: halobetasol                       |    HIV edge pred:     0.8658
# Drug: Lutropin alfa                     |    HIV edge pred:     0.8654
# Drug: palifermin                        |    HIV edge pred:     0.8653
# Drug: DIHYDROERGOCRISTINE               |    HIV edge pred:     0.8638
# Drug: ivacaftor                         |    HIV edge pred:     0.8636
# Drug: tramadol                          |    HIV edge pred:     0.8632
# Drug: nan                               |    HIV edge pred:     0.8603
# Drug: valrubicin                        |    HIV edge pred:     0.8588
# Drug: Arformoterol                      |    HIV edge pred:     0.8582
# Drug: tetrabenazine                     |    HIV edge pred:     0.8581
# Drug: dapiprazole                       |    HIV edge pred:     0.8573
# Drug: tofacitinib                       |    HIV edge pred:     0.8565
# Drug: secukinumab                       |    HIV edge pred:     0.8563
# Drug: nan                               |    HIV edge pred:     0.8542
# Drug: memantine                         |    HIV edge pred:     0.8535
# Drug: oxandrolone                       |    HIV edge pred:     0.8534
# Drug: bosentan                          |    HIV edge pred:     0.8527
# Drug: bromperidol                       |    HIV edge pred:     0.8516
# Drug: carbimazole                       |    HIV edge pred:      0.851
# Drug: olanzapine                        |    HIV edge pred:     0.8484
# Drug: etofibrate                        |    HIV edge pred:     0.8474
# Drug: triflusal                         |    HIV edge pred:     0.8473
# Drug: THROMBIN ALFA                     |    HIV edge pred:      0.847
# Drug: trichlormethiazide                |    HIV edge pred:     0.8461
# Drug: zonisamide                        |    HIV edge pred:      0.846
# Drug: Albiglutide                       |    HIV edge pred:     0.8456
# Drug: eletriptan                        |    HIV edge pred:     0.8447
# Drug: nan                               |    HIV edge pred:     0.8446
# Drug: vernakalant                       |    HIV edge pred:     0.8444
# Drug: bambuterol                        |    HIV edge pred:     0.8432
# Drug: nimesulide                        |    HIV edge pred:     0.8414
# Drug: Phenazopyridine                   |    HIV edge pred:     0.8403
# Drug: progesterone                      |    HIV edge pred:     0.8378
# Drug: tiotropium                        |    HIV edge pred:     0.8373
# Drug: Rimonabant                        |    HIV edge pred:     0.8361
# Drug: mebeverine                        |    HIV edge pred:      0.836
# Drug: etifoxine                         |    HIV edge pred:      0.836
# Drug: fenofibric-acid                   |    HIV edge pred:     0.8353
# Drug: Ximelagatran                      |    HIV edge pred:     0.8304
# Drug: dabrafenib                        |    HIV edge pred:     0.8268
# Drug: candesartan                       |    HIV edge pred:     0.8266
# Drug: NONACOG BETA PEGOL                |    HIV edge pred:     0.8264
# Drug: retigabine                        |    HIV edge pred:     0.8255
# Drug: meloxicam                         |    HIV edge pred:     0.8254
# Drug: pinaverium                        |    HIV edge pred:      0.824
# Drug: fluphenazine                      |    HIV edge pred:     0.8229
# Drug: aminosalicylate                   |    HIV edge pred:     0.8228
# Drug: Flurazepam                        |    HIV edge pred:     0.8226
# Drug: lumacaftor                        |    HIV edge pred:      0.822
# Drug: tocainide                         |    HIV edge pred:     0.8218
# Drug: prednisone                        |    HIV edge pred:     0.8181
# Drug: Insulin Degludec                  |    HIV edge pred:     0.8171
# Drug: ospemifene                        |    HIV edge pred:     0.8159
# Drug: fenofibrate                       |    HIV edge pred:     0.8156
# Drug: ethinyl-estradiol                 |    HIV edge pred:     0.8138
# Drug: nan                               |    HIV edge pred:     0.8137
# Drug: Aranidipine                       |    HIV edge pred:     0.8103
# Drug: ALCLOMETASONE                     |    HIV edge pred:     0.8038
# Drug: metreleptin                       |    HIV edge pred:     0.8024
# Drug: lacosamide                        |    HIV edge pred:     0.8014
# Drug: eprosartan                        |    HIV edge pred:     0.8008
# Drug: DUPILUMAB                         |    HIV edge pred:     0.8005
# Drug: suvorexant                        |    HIV edge pred:     0.8001
# Drug: nabumetone                        |    HIV edge pred:     0.7993
# Drug: homatropine                       |    HIV edge pred:     0.7991
# Drug: nan                               |    HIV edge pred:     0.7982
# Drug: Dezocine                          |    HIV edge pred:     0.7965
# Drug: sotalol                           |    HIV edge pred:     0.7929
# Drug: bromocriptine                     |    HIV edge pred:     0.7915
# Drug: anagliptin                        |    HIV edge pred:     0.7873
# Drug: cinacalcet                        |    HIV edge pred:     0.7867
# Drug: domperidone                       |    HIV edge pred:     0.7859
# Drug: levothyroxine                     |    HIV edge pred:     0.7822
# Drug: droxicam                          |    HIV edge pred:     0.7816
# Drug: Encainide                         |    HIV edge pred:     0.7805
# Drug: cinchocaine                       |    HIV edge pred:     0.7768
# Drug: tripelennamine                    |    HIV edge pred:     0.7764
# Drug: Testosterone Propionate           |    HIV edge pred:     0.7761
# Drug: betamethasone                     |    HIV edge pred:      0.776
# Drug: Midazolam                         |    HIV edge pred:     0.7733
# Drug: alosetron                         |    HIV edge pred:     0.7715
# Drug: almotriptan                       |    HIV edge pred:     0.7701
# Drug: ulipristal                        |    HIV edge pred:     0.7673
# Drug: chenodeoxycholic-acid             |    HIV edge pred:     0.7639
# Drug: bopindolol                        |    HIV edge pred:     0.7637
# Drug: quinagolide                       |    HIV edge pred:     0.7634
# Drug: milrinone                         |    HIV edge pred:      0.763
# Drug: deserpidine                       |    HIV edge pred:     0.7628
# Drug: Adenosine monophosphate           |    HIV edge pred:     0.7627
# Drug: Filgrastim                        |    HIV edge pred:     0.7623
# Drug: bendroflumethiazide               |    HIV edge pred:     0.7618
# Drug: cimetropium                       |    HIV edge pred:     0.7605
# Drug: sunitinib                         |    HIV edge pred:      0.758
# Drug: azosemide                         |    HIV edge pred:     0.7571
# Drug: indobufen                         |    HIV edge pred:      0.756
# Drug: oxazepam                          |    HIV edge pred:     0.7558
# Drug: melatonin                         |    HIV edge pred:     0.7546
# Drug: procarbazine                      |    HIV edge pred:     0.7527
# Drug: nan                               |    HIV edge pred:      0.752
# Drug: budesonide                        |    HIV edge pred:     0.7515
# Drug: bupropion                         |    HIV edge pred:     0.7514
# Drug: nan                               |    HIV edge pred:     0.7511
# Drug: cefotaxime                        |    HIV edge pred:     0.7507
# Drug: Streptokinase                     |    HIV edge pred:     0.7504
# Drug: miconazole                        |    HIV edge pred:     0.7501
# Drug: dexamethasone                     |    HIV edge pred:       0.75
# Drug: ibuproxam                         |    HIV edge pred:     0.7495
# Drug: tropicamide                       |    HIV edge pred:     0.7495
# Drug: MOROCTOCOG ALFA                   |    HIV edge pred:     0.7481
# Drug: levofloxacin                      |    HIV edge pred:      0.748
# Drug: Pergolide                         |    HIV edge pred:     0.7477
# Drug: dextroamphetamine                 |    HIV edge pred:     0.7473
# Drug: meclizine                         |    HIV edge pred:     0.7455
# Drug: mestranol                         |    HIV edge pred:     0.7454
# Drug: reboxetine                        |    HIV edge pred:     0.7451
# Drug: repaglinide                       |    HIV edge pred:     0.7432
# Drug: ouabain                           |    HIV edge pred:      0.743
# Drug: dutasteride                       |    HIV edge pred:     0.7397
# Drug: nan                               |    HIV edge pred:     0.7384
# Drug: leucovorin                        |    HIV edge pred:     0.7382
# Drug: Potassium perchlorate             |    HIV edge pred:      0.738
# Drug: cyanocobalamin                    |    HIV edge pred:     0.7376
# Drug: eucalyptol                        |    HIV edge pred:     0.7375
# Drug: nalmefene                         |    HIV edge pred:     0.7365
# Drug: Levomilnacipran                   |    HIV edge pred:     0.7364
# Drug: degarelix                         |    HIV edge pred:     0.7357
# Drug: idarubicin                        |    HIV edge pred:     0.7352
# Drug: hydroquinone                      |    HIV edge pred:     0.7346
# Drug: epinastine                        |    HIV edge pred:     0.7342
# Drug: Talbutal                          |    HIV edge pred:     0.7333
# Drug: mometasone                        |    HIV edge pred:     0.7323
# Drug: Lisdexamfetamine                  |    HIV edge pred:     0.7308
# Drug: doxofylline                       |    HIV edge pred:     0.7306
# Drug: blonanserin                       |    HIV edge pred:     0.7304
# Drug: bezafibrate                       |    HIV edge pred:     0.7303
# Drug: capsicum oleoresin                |    HIV edge pred:       0.73
# Drug: propafenone                       |    HIV edge pred:     0.7299
# Drug: testolactone                      |    HIV edge pred:     0.7295
# Drug: nan                               |    HIV edge pred:     0.7291
# Drug: flucytosine                       |    HIV edge pred:      0.729
# Drug: tacrine                           |    HIV edge pred:     0.7279
# Drug: vardenafil                        |    HIV edge pred:     0.7277
# Drug: Ritonavir                         |    HIV edge pred:     0.7276
# Drug: Nitroprusside                     |    HIV edge pred:      0.727
# Drug: eltrombopag                       |    HIV edge pred:     0.7267
# Drug: pyrazinamide                      |    HIV edge pred:      0.726
# Drug: Heparin                           |    HIV edge pred:     0.7257
# Drug: GAMMA-AMINOBUTYRIC ACID           |    HIV edge pred:     0.7253
# Drug: ciprofibrate                      |    HIV edge pred:     0.7249
# Drug: netupitant                        |    HIV edge pred:     0.7239
# Drug: pentostatin                       |    HIV edge pred:     0.7239
# Drug: isoflurophate                     |    HIV edge pred:     0.7238
# Drug: dimercaprol                       |    HIV edge pred:     0.7224
# Drug: diflunisal                        |    HIV edge pred:     0.7209
# Drug: Lactose                           |    HIV edge pred:     0.7208
# Drug: Denosumab                         |    HIV edge pred:     0.7198
# Drug: phenoxybenzamine                  |    HIV edge pred:     0.7169
# Drug: Secobarbital                      |    HIV edge pred:     0.7163
# Drug: IRON DEXTRAN                      |    HIV edge pred:     0.7156
# Drug: nan                               |    HIV edge pred:     0.7152
# Drug: Tocilizumab                       |    HIV edge pred:     0.7144
# Drug: naloxegol                         |    HIV edge pred:     0.7131
# Drug: trandolapril                      |    HIV edge pred:     0.7124
# Drug: ergotamine                        |    HIV edge pred:     0.7124
# Drug: nan                               |    HIV edge pred:     0.7118
# Drug: darifenacin                       |    HIV edge pred:     0.7106
# Drug: atropine                          |    HIV edge pred:     0.7104
# Drug: esmolol                           |    HIV edge pred:     0.7102
# Drug: tandospirone                      |    HIV edge pred:       0.71
# Drug: cholecalciferol                   |    HIV edge pred:     0.7095
# Drug: ertugliflozin                     |    HIV edge pred:     0.7089
# Drug: Niclosamide                       |    HIV edge pred:     0.7078
# Drug: nan                               |    HIV edge pred:     0.7068
# Drug: zaleplon                          |    HIV edge pred:     0.7061
# Drug: nan                               |    HIV edge pred:     0.7051
# Drug: naproxen                          |    HIV edge pred:     0.7047
# Drug: nan                               |    HIV edge pred:     0.7043
# Drug: dapagliflozin                     |    HIV edge pred:      0.704
# Drug: Kappadione                        |    HIV edge pred:     0.7039
# Drug: molsidomine                       |    HIV edge pred:     0.7038
# Drug: 5-fluorouracil                    |    HIV edge pred:      0.702
# Drug: dihydroergotamine                 |    HIV edge pred:      0.701
# Drug: nan                               |    HIV edge pred:     0.7001
# Drug: nan                               |    HIV edge pred:     0.6992
# Drug: brexpiprazole                     |    HIV edge pred:     0.6988
# Drug: coenzyme Q10                      |    HIV edge pred:     0.6986
# Drug: bimatoprost                       |    HIV edge pred:     0.6986
# Drug: noretynodrel                      |    HIV edge pred:     0.6982
# Drug: avanafil                          |    HIV edge pred:     0.6981
# Drug: desonide                          |    HIV edge pred:      0.696
# Drug: Teriparatide                      |    HIV edge pred:     0.6957
# Drug: Glycerin                          |    HIV edge pred:      0.694
# Drug: L-Aspartic Acid                   |    HIV edge pred:     0.6939
# Drug: pipamperone                       |    HIV edge pred:     0.6927
# Drug: isoprenaline                      |    HIV edge pred:     0.6926
# Drug: nan                               |    HIV edge pred:     0.6917
# Drug: cevimeline                        |    HIV edge pred:     0.6913
# Drug: phenazone                         |    HIV edge pred:     0.6907
# Drug: haloperidol                       |    HIV edge pred:     0.6892
# Drug: Chlordiazepoxide                  |    HIV edge pred:     0.6884
# Drug: phenytoin                         |    HIV edge pred:     0.6881
# Drug: edoxaban                          |    HIV edge pred:      0.686
# Drug: azathioprine                      |    HIV edge pred:      0.686
# Drug: gefitinib                         |    HIV edge pred:     0.6858
# Drug: nicorandil                        |    HIV edge pred:     0.6852
# Drug: Alirocumab                        |    HIV edge pred:     0.6848
# Drug: febuxostat                        |    HIV edge pred:     0.6845
# Drug: nan                               |    HIV edge pred:     0.6844
# Drug: pomalidomide                      |    HIV edge pred:     0.6844
# Drug: sildenafil                        |    HIV edge pred:     0.6828
# Drug: Isoniazid                         |    HIV edge pred:     0.6816
# Drug: pimecrolimus                      |    HIV edge pred:     0.6815
# Drug: minocycline                       |    HIV edge pred:     0.6809
# Drug: perphenazine                      |    HIV edge pred:     0.6801
# Drug: Magnesium Sulfate                 |    HIV edge pred:       0.68
# Drug: nan                               |    HIV edge pred:       0.68
# Drug: nan                               |    HIV edge pred:     0.6793
# Drug: tocofersolan                      |    HIV edge pred:     0.6785
# Drug: pazopanib                         |    HIV edge pred:     0.6774
# Drug: Alteplase                         |    HIV edge pred:      0.677
# Drug: sulfasalazine                     |    HIV edge pred:     0.6766
# Drug: Insulin Glulisine                 |    HIV edge pred:     0.6736
# Drug: prednicarbate                     |    HIV edge pred:     0.6723
# Drug: Butethal                          |    HIV edge pred:     0.6712
# Drug: trovafloxacin                     |    HIV edge pred:     0.6704
# Drug: cortisone-acetate                 |    HIV edge pred:     0.6696
# Drug: palonosetron                      |    HIV edge pred:     0.6694
# Drug: ruxolitinib                       |    HIV edge pred:     0.6681
# Drug: cyclandelate                      |    HIV edge pred:     0.6681
# Drug: sarilumab                         |    HIV edge pred:     0.6651
# Drug: nan                               |    HIV edge pred:     0.6647
# Drug: nan                               |    HIV edge pred:     0.6647
# Drug: prucalopride                      |    HIV edge pred:     0.6647
# Drug: irbesartan                        |    HIV edge pred:     0.6636
# Drug: propofol                          |    HIV edge pred:     0.6626
# Drug: deferoxamine-mesylate             |    HIV edge pred:     0.6616
# Drug: Digitoxin                         |    HIV edge pred:     0.6612
# Drug: levodopa                          |    HIV edge pred:     0.6609
# Drug: amiloride                         |    HIV edge pred:     0.6602
# Drug: niflumic-acid                     |    HIV edge pred:     0.6595
# Drug: ipratropium                       |    HIV edge pred:     0.6592
# Drug: chloramphenicol                   |    HIV edge pred:     0.6588
# Drug: stanozolol                        |    HIV edge pred:     0.6583
# Drug: tridihexethyl                     |    HIV edge pred:     0.6576
# Drug: phentermine                       |    HIV edge pred:     0.6576
# Drug: mirtazapine                       |    HIV edge pred:     0.6574
# Drug: Azilsartan medoxomil              |    HIV edge pred:     0.6552
# Drug: dydrogesterone                    |    HIV edge pred:     0.6552
# Drug: Clorazepate                       |    HIV edge pred:     0.6542
# Drug: nan                               |    HIV edge pred:      0.653
# Drug: taurine                           |    HIV edge pred:     0.6523
# Drug: thiopental                        |    HIV edge pred:       0.65
# Drug: topiramate                        |    HIV edge pred:     0.6498
# Drug: nan                               |    HIV edge pred:     0.6494
# Drug: abiraterone                       |    HIV edge pred:     0.6466
# Drug: travoprost                        |    HIV edge pred:      0.646
# Drug: naratriptan                       |    HIV edge pred:     0.6448
# Drug: Glycopyrronium                    |    HIV edge pred:     0.6448
# Drug: saxagliptin                       |    HIV edge pred:     0.6435
# Drug: tranilast                         |    HIV edge pred:     0.6411
# Drug: isopropamide-iodide               |    HIV edge pred:     0.6407
# Drug: xylometazoline                    |    HIV edge pred:     0.6397
# Drug: pranlukast                        |    HIV edge pred:     0.6397
# Drug: nan                               |    HIV edge pred:     0.6377
# ...
# DZ: Aplastic Anemia                   |    HIV edge pred:      10.44
# DZ: Glioblastoma Multiforme           |    HIV edge pred:      10.44
# DZ: hypereosinophilic syndrome (HES)    |    HIV edge pred:      10.39
# DZ: Venous Thrombosis                 |    HIV edge pred:      10.38
# DZ: hypoparathyroidism                |    HIV edge pred:      10.37
# DZ: hypothyroidism                    |    HIV edge pred:      10.37
# DZ: liposarcoma                       |    HIV edge pred:      10.36
# DZ: Epididymitis                      |    HIV edge pred:      10.32
# DZ: fever                             |    HIV edge pred:      10.32
# DZ: nausea                            |    HIV edge pred:      10.31
# DZ: Neoplasm Metastasis               |    HIV edge pred:      10.31
# DZ: Infarction                        |    HIV edge pred:       10.3
# DZ: Allergic Rhinitis (Disorder)      |    HIV edge pred:      10.29
# DZ: thrombocytopenia                  |    HIV edge pred:      10.27
# DZ: Parathyroid Gland Adenocarcinoma    |    HIV edge pred:      10.22
# DZ: Dystrophia Unguium                |    HIV edge pred:       10.2
# DZ: Mixed anxiety and depressive disorder    |    HIV edge pred:      10.18
# DZ: Acute Basophilic Leukemia         |    HIV edge pred:      10.15
# DZ: Brain Abscess                     |    HIV edge pred:      10.15
# DZ: Aortic coarctation                |    HIV edge pred:      10.13
# DZ: follicular lymphoma               |    HIV edge pred:      10.11
# DZ: Prostatic Hyperplasia             |    HIV edge pred:      10.09
# DZ: Xerosis                           |    HIV edge pred:      10.08
# DZ: Acute Lymphocytic Leukemia        |    HIV edge pred:      10.01
# DZ: Ichthyoses                        |    HIV edge pred:      10.01
# DZ: Angioedemas, Hereditary           |    HIV edge pred:       10.0
# DZ: Lymphoid Leukemia                 |    HIV edge pred:      9.969
# DZ: narcolepsy                        |    HIV edge pred:      9.965
# DZ: bipolar disorder                  |    HIV edge pred:      9.927
# DZ: Hypertensive disease              |    HIV edge pred:      9.907
# DZ: Carcinoma, Pancreatic Ductal      |    HIV edge pred:      9.894
# DZ: Ascites                           |    HIV edge pred:      9.836
# DZ: Adrenal Gland Hypofunction        |    HIV edge pred:      9.754
# DZ: HIV                               |    HIV edge pred:      9.744
# DZ: thiamine deficiency               |    HIV edge pred:      9.727
# DZ: Malignant Neoplasm Of Breast      |    HIV edge pred:      9.705
# DZ: Malnutrition                      |    HIV edge pred:      9.661
# DZ: Behcet Syndrome                   |    HIV edge pred:      9.656
# DZ: Amyloidosis                       |    HIV edge pred:      9.601
# DZ: Familial Mediterranean Fever      |    HIV edge pred:      9.587
# DZ: Polycystic Kidney, Autosomal Dominant    |    HIV edge pred:      9.585
# DZ: Colorectal Neoplasms              |    HIV edge pred:      9.567
# DZ: ventricular fibrillation (VF)     |    HIV edge pred:      9.527
# DZ: Raynaud's disease                 |    HIV edge pred:      9.523
# DZ: Blast Phase                       |    HIV edge pred:      9.508
# DZ: subependymal giant cell astrocytoma (SEGA)    |    HIV edge pred:      9.469
# DZ: neuroblastoma                     |    HIV edge pred:       9.44
# DZ: diabetic nephropathy              |    HIV edge pred:      9.432
# DZ: Hyperplasia                       |    HIV edge pred:      9.432
# DZ: Stargardt's disease               |    HIV edge pred:      9.398
# DZ: Histiocytosis                     |    HIV edge pred:      9.381
# DZ: Acute Erythroblastic Leukemia     |    HIV edge pred:      9.334
# DZ: heartburn                         |    HIV edge pred:      9.333
# DZ: Dyspnea                           |    HIV edge pred:      9.304
# DZ: Inappropriate Adh Syndrome        |    HIV edge pred:      9.299
# DZ: hypercholesterolemia              |    HIV edge pred:       9.28
# DZ: hyperlipidemia                    |    HIV edge pred:      9.236
# DZ: atrial fibrillation (AF)          |    HIV edge pred:      9.233
# DZ: Hemophilia A                      |    HIV edge pred:      9.231
# DZ: Lactose Intolerance               |    HIV edge pred:      9.185
# DZ: hypotension                       |    HIV edge pred:      9.178
# DZ: Cellulitis                        |    HIV edge pred:      9.164
# DZ: Bronchiolitis                     |    HIV edge pred:       9.16
# DZ: Metabolic Syndrome X              |    HIV edge pred:      9.151
# DZ: Bladder Neoplasm                  |    HIV edge pred:      9.087
# DZ: methemoglobinemia                 |    HIV edge pred:      9.077
# DZ: Myocardial Infarction             |    HIV edge pred:      9.032
# DZ: Serum Sickness                    |    HIV edge pred:      9.029
# DZ: Gastric Ulcer                     |    HIV edge pred:      9.024
# DZ: Schizoaffective Disorder          |    HIV edge pred:      9.008
# DZ: Multiple Acyl Coenzyme A Dehydrogenase Deficiency    |    HIV edge pred:      8.984
# DZ: Systemic Scleroderma              |    HIV edge pred:      8.895
# DZ: hypoglycemia                      |    HIV edge pred:      8.874
# DZ: Hypertrophic Cardiomyopathy       |    HIV edge pred:      8.857
# DZ: Supraventricular Tachycardia      |    HIV edge pred:      8.771
# DZ: Zellweger syndrome                |    HIV edge pred:      8.761
# DZ: Alcohol Withdrawal Syndrome       |    HIV edge pred:      8.751
# DZ: Tyrosinemia, Type I               |    HIV edge pred:      8.744
# DZ: chronic lymphocytic leukemia (CLL)    |    HIV edge pred:       8.71
# DZ: Hyperkalemia                      |    HIV edge pred:      8.642
# DZ: Bone Neoplasms                    |    HIV edge pred:      8.633
# DZ: Kaposi sarcoma                    |    HIV edge pred:      8.624
# DZ: Bartter Disease                   |    HIV edge pred:      8.582
# DZ: Infection of bone                 |    HIV edge pred:      8.556
# DZ: spasms                            |    HIV edge pred:      8.545
# DZ: pyelonephritis                    |    HIV edge pred:      8.525
# DZ: gestational trophoblastic disease (GTD)    |    HIV edge pred:      8.509
# DZ: Bronchopulmonary Dysplasia        |    HIV edge pred:       8.46
# DZ: hepatocellular carcinoma (HCC)    |    HIV edge pred:       8.38
# DZ: idiopathic pulmonary fibrosis (IPF)    |    HIV edge pred:      8.357
# DZ: Hyperkeratosis                    |    HIV edge pred:      8.355
# DZ: meningitis                        |    HIV edge pred:      8.343
# DZ: Keratoconjunctivitis Sicca        |    HIV edge pred:       8.27
# DZ: ventricular tachycardia (VT)      |    HIV edge pred:      8.197
# DZ: Apnea                             |    HIV edge pred:      8.187
# DZ: tuberculosis                      |    HIV edge pred:      8.178
# DZ: Chronic Neutrophilic Leukemia     |    HIV edge pred:      8.137
# DZ: Wilson's disease                  |    HIV edge pred:      8.098
# DZ: psoriasis                         |    HIV edge pred:      8.064
# DZ: Alzheimer's disease               |    HIV edge pred:      8.058
# DZ: Coughing                          |    HIV edge pred:      8.025
# DZ: keratosis                         |    HIV edge pred:      8.017
# DZ: Acidosis                          |    HIV edge pred:      7.994
# DZ: Meningococcal Meningitis          |    HIV edge pred:      7.965
# DZ: Erysipelas                        |    HIV edge pred:       7.95
# DZ: peripheral neuropathy             |    HIV edge pred:      7.903
# DZ: astrocytoma                       |    HIV edge pred:      7.886
# DZ: Atrial Flutter                    |    HIV edge pred:      7.849
# DZ: Cholecystitis                     |    HIV edge pred:      7.838
# DZ: Septicemia                        |    HIV edge pred:      7.813
# DZ: Tetralogy of Fallot               |    HIV edge pred:      7.806
# DZ: Head And Neck Neoplasms           |    HIV edge pred:      7.778
# DZ: amyotrophic lateral sclerosis (ALS)    |    HIV edge pred:      7.749
# DZ: seizures                          |    HIV edge pred:      7.742
# DZ: Hepatitis C, Chronic              |    HIV edge pred:       7.69
# DZ: Allergy; Nasal                    |    HIV edge pred:      7.674
# DZ: Pulmonary Hypertension            |    HIV edge pred:      7.666
# DZ: coronary artery disease (CAD)     |    HIV edge pred:      7.657
# DZ: heterotopic ossification          |    HIV edge pred:      7.655
# DZ: Mycosis Fungoides                 |    HIV edge pred:      7.565
# DZ: Hodgkin's lymphoma                |    HIV edge pred:      7.546
# DZ: hepatic encephalopathy (HE)       |    HIV edge pred:      7.513
# DZ: Skin Neoplasms                    |    HIV edge pred:      7.418
# DZ: Hay Fever                         |    HIV edge pred:      7.406
# DZ: Allergic Reaction                 |    HIV edge pred:      7.404
# DZ: brittle bone disease              |    HIV edge pred:      7.372
# DZ: conjunctivitis                    |    HIV edge pred:      7.358
# DZ: Hemangioma                        |    HIV edge pred:      7.341
# DZ: Leukemia, Myelocytic, Acute       |    HIV edge pred:      7.309
# DZ: epilepsy                          |    HIV edge pred:      7.232
# DZ: Streptococcal Pneumonia           |    HIV edge pred:      7.169
# DZ: Uremia                            |    HIV edge pred:      7.093
# DZ: cardiomyopathy                    |    HIV edge pred:      7.058
# DZ: Erythema Nodosum                  |    HIV edge pred:      7.034
# DZ: cardiac arrest                    |    HIV edge pred:      7.006
# DZ: Ovarian Neoplasm                  |    HIV edge pred:      6.914
# DZ: Iron Deficiency Anemia            |    HIV edge pred:      6.882
# DZ: Malignant Neoplasm Of Pancreas    |    HIV edge pred:      6.783
# DZ: Gingivostomatitis                 |    HIV edge pred:      6.778
# DZ: spinocerebellar ataxia            |    HIV edge pred:      6.765
# DZ: Migraine Disorders                |    HIV edge pred:      6.672
# DZ: multiple sclerosis                |    HIV edge pred:      6.622
# DZ: Familial hypercholesterolemia - homozygous    |    HIV edge pred:      6.454
# DZ: peritonitis                       |    HIV edge pred:      6.437
# DZ: hypertriglyceridemia              |    HIV edge pred:      6.369
# DZ: Pre-Eclampsia                     |    HIV edge pred:       6.33
# DZ: enteritis                         |    HIV edge pred:      6.307
# DZ: Sezary Syndrome                   |    HIV edge pred:      6.242
# DZ: Myeloid Leukemia                  |    HIV edge pred:      6.211
# DZ: Kidney Neoplasm                   |    HIV edge pred:      6.156
# DZ: Non-Small Cell Lung Carcinoma     |    HIV edge pred:      6.018
# DZ: Hepatitis B, Chronic              |    HIV edge pred:      5.899
# DZ: macular degeneration              |    HIV edge pred:      5.886
# DZ: Thrombocythemia, Essential        |    HIV edge pred:      5.871
# DZ: melanoma                          |    HIV edge pred:      5.849
# DZ: Leukemia                          |    HIV edge pred:      5.545
# DZ: Hyperlipoproteinemia Type V       |    HIV edge pred:      5.476
# DZ: Stomach Neoplasms                 |    HIV edge pred:      5.438
# DZ: colorectal cancer                 |    HIV edge pred:      5.379
# DZ: hypokalemia                       |    HIV edge pred:      5.379
# DZ: renal cell carcinoma (RCC)        |    HIV edge pred:      5.274
# DZ: Colonic Neoplasms                 |    HIV edge pred:      5.097
# DZ: Acute Myelomonocytic Leukemia     |    HIV edge pred:      5.084
# DZ: hypercalcemia                     |    HIV edge pred:      4.889
# DZ: carnitine deficiency              |    HIV edge pred:      4.836
# DZ: Paroxysmal Supraventricular Tachycardia    |    HIV edge pred:      4.805
# DZ: Esophagitis                       |    HIV edge pred:      4.804
# DZ: hypocalcemia                      |    HIV edge pred:      4.786
# DZ: obesity                           |    HIV edge pred:      4.769
# DZ: Pancreatic Neoplasm               |    HIV edge pred:      4.764
# DZ: Osteitis Deformans                |    HIV edge pred:      4.724
# DZ: eczema                            |    HIV edge pred:      4.713
# DZ: headache                          |    HIV edge pred:      4.582
# DZ: cervical cancer                   |    HIV edge pred:      4.579
# DZ: squamous cell carcinoma           |    HIV edge pred:      4.429
# DZ: Multiple Endocrine Neoplasia      |    HIV edge pred:      4.371
# DZ: Hypocalcemic tetany               |    HIV edge pred:      4.356
# DZ: Hyperlipoproteinemia Type Iv      |    HIV edge pred:      4.347
# DZ: tetany                            |    HIV edge pred:      4.346
# DZ: Testicular Germ Cell Tumor        |    HIV edge pred:      4.299
# DZ: Brain Neoplasms                   |    HIV edge pred:      4.157
# DZ: schizophrenia                     |    HIV edge pred:      4.139
# DZ: Gaucher disease                   |    HIV edge pred:       3.93
# DZ: Herpes Encephalitis               |    HIV edge pred:      3.916
# DZ: Osteoporosis, Postmenopausal      |    HIV edge pred:      3.889
# DZ: Lymphoma                          |    HIV edge pred:      3.845
# DZ: Carcinoma, Small Cell             |    HIV edge pred:      3.803
# DZ: Multiple Sclerosis, Relapsing-Remitting    |    HIV edge pred:      3.759
# DZ: schistosomiasis                   |    HIV edge pred:       3.68
# DZ: skin ulcer                        |    HIV edge pred:      3.642
# DZ: pulmonary arterial hypertension (PAH)    |    HIV edge pred:      3.456
# DZ: polycythemia vera                 |    HIV edge pred:      3.354
# DZ: Pituitary Dwarfism                |    HIV edge pred:      3.219
# DZ: hairy cell leukemia               |    HIV edge pred:      3.186
# DZ: ocular hypertension               |    HIV edge pred:      3.121
# DZ: Malignant Carcinoid Syndrome      |    HIV edge pred:      2.946
# DZ: ichthyosis vulgaris               |    HIV edge pred:       2.83
# DZ: Diabetes Mellitus, Non-Insulin-Dependent    |    HIV edge pred:      2.686
# DZ: Rectal Neoplasms                  |    HIV edge pred:       2.65
# DZ: gastritis                         |    HIV edge pred:      2.649
# DZ: pneumonia                         |    HIV edge pred:      2.552
# DZ: Mammary Neoplasms                 |    HIV edge pred:      2.521
# DZ: Peptic Ulcer                      |    HIV edge pred:      2.346
# DZ: Obesity, Abdominal                |    HIV edge pred:      2.295
# DZ: Malignant Neoplasm Of Ovary       |    HIV edge pred:      2.276
# DZ: osteoporosis                      |    HIV edge pred:       2.15
# DZ: diabetes mellitus                 |    HIV edge pred:      2.022
# DZ: hyperglycemia                     |    HIV edge pred:      2.012
# DZ: Ulcer                             |    HIV edge pred:      1.832
# DZ: Hiv Wasting Syndrome              |    HIV edge pred:      1.544
# DZ: dry eye syndrome                  |    HIV edge pred:      1.543
# DZ: Zollinger-Ellison syndrome        |    HIV edge pred:      1.432
# DZ: Carcinogenesis                    |    HIV edge pred:      1.304
# DZ: onychomycosis                     |    HIV edge pred:      1.238
# DZ: Thyroid Neoplasm                  |    HIV edge pred:      1.214
# DZ: chronic myeloid leukemia (CML)    |    HIV edge pred:      1.001
# DZ: Lung Neoplasms                    |    HIV edge pred:     0.9118
# DZ: Duodenal Ulcer                    |    HIV edge pred:     0.8737
# DZ: Mastocytosis, Systemic            |    HIV edge pred:     0.7935
# DZ: glaucoma                          |    HIV edge pred:     0.5534
# DZ: Small Cell Carcinoma Of Lung      |    HIV edge pred:     0.4444
# DZ: gastroesophageal reflux disease (GERD)    |    HIV edge pred:      0.283
# DZ: Gastrointestinal Hemorrhage       |    HIV edge pred:    0.05861
# DZ: non-Hodgkin lymphoma (NHL)        |    HIV edge pred:   -0.08777
# DZ: Peptic Esophagitis                |    HIV edge pred:    -0.4009
# DZ: peripheral artery disease (PAD)    |    HIV edge pred:    -0.5745
# DZ: infertility                       |    HIV edge pred:    -0.6129
# DZ: stroke                            |    HIV edge pred:    -0.6623
# DZ: multiple myeloma                  |    HIV edge pred:     -1.325
# DZ: hemorrhage                        |    HIV edge pred:     -1.633

# %%
# Write results to file
#res_df.to_csv("../results/res1_loss0.47_auc0.76.tsv", sep="\t", index=False)
